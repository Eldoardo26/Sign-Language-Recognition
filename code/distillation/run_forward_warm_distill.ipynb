# %% [markdown]
# # FD-CMKD warm-start
#
# This is the regime the thesis reports: the student is **warm-started** from the
# converged CTC-only baseline and fine-tuned with the FD-CMKD transfer loss at a
# small, re-tuned learning rate. It answers *does the teacher improve an
# already-trained student?*
#
# It is the twin of `run_from_scratch_distill.ipynb`. The two notebooks are identical
# except for the config they load: this one uses `warm_start_fd_cmkd.yaml`, which
# carries `load_model` and the small learning rate; the other trains from random
# initialization at the baseline learning rate with a distillation-weight warmup.
# Running both and comparing each against the CTC-only baseline (39.54 dev / 41.53
# test) separates the effect of the teacher from the effect of the training regime.
#
# **On the comparison.** Warm-start confounds the transfer with extra fine-tuning:
# the distilled student sees more gradient steps than the baseline and a fresh lr
# search. Read against the starting checkpoint it is not evidence; the sound
# comparison is the matched control of `run_optuna.ipynb`. This notebook exists to
# reproduce the reported warm-start numbers and to pair cleanly with the from-scratch
# run.

# %%
# Run from code/distillation/ no matter where the kernel was launched.
import os
if not os.path.exists('fd_cmkd.py'):
    _cwd = os.getcwd()
    for _k in range(0, 6):
        _base = os.path.abspath(os.path.join(_cwd, *(['..'] * _k)))
        _cand = os.path.join(_base, 'code', 'distillation')
        if os.path.exists(os.path.join(_cand, 'fd_cmkd.py')):
            os.chdir(_cand); break
        if os.path.exists(os.path.join(_base, 'fd_cmkd.py')):
            os.chdir(_base); break
print('working dir:', os.getcwd())

# Where this run writes -- same convention as the other notebooks.
# Output goes to runs/<RUN_NAME>/; dataset/checkpoints/ is never touched.
import os

RUN_NAME  = 'forward_warm_133'   # nuovo teacher RTMW-133 (non sovrascrive i run vecchi)
OVERWRITE = False        # False: version to _002, _003, ... instead of deleting
DO_TRAIN  = True         # True: esegue la distillazione (warm-start, early-stopped)

RUN_DIR = os.path.join('../../runs', RUN_NAME)
if os.path.exists(RUN_DIR) and not OVERWRITE:
    _n = 2
    while os.path.exists('%s_%03d' % (RUN_DIR, _n)):
        _n += 1
    RUN_DIR = '%s_%03d' % (RUN_DIR, _n)
print('this run writes to:', os.path.normpath(os.path.abspath(RUN_DIR)))

# This notebook evaluates only its own run.
EVAL_CKPT = 'mine'
# Out:
# working dir: /home/ebufi/Sign-Language-Recognition/code/distillation
# this run writes to: /home/ebufi/Sign-Language-Recognition/runs/forward_warm_133_006

# %%
import sys, yaml

SIGNFORMER_DIR = os.path.abspath('../signformer')   # for `import main.*`
NB_DIR = os.path.abspath('.')                        # for `import fd_cmkd*`
for _p in (SIGNFORMER_DIR, NB_DIR):
    if _p not in sys.path:
        sys.path.insert(0, _p)

import main.training as mt
from fd_cmkd_trainer import train_fd_cmkd
from fd_cmkd import load_teacher_feats
print('imports OK')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784298819.295717 2434871 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# imports OK

# %%
# ── Teacher features: guard + provenienza + (se mancano) estrazione ──
import os, yaml

# use the config THIS notebook loads (BASE_CFG); fall back to the warm one
_cfg_file = globals().get('BASE_CFG', 'warm_start_fd_cmkd.yaml')
_dc = yaml.safe_load(open(_cfg_file))['training']['distillation']
FEAT_DIR   = _dc['teacher_feats_dir']
_train_pkl = os.path.join(FEAT_DIR, 'train.pkl')

# GUARD: dev'essere il nuovo teacher, non il MediaPipe vecchio
assert 'skeleton_feats_133' in FEAT_DIR, f"STOP: teacher VECCHIO nel config! ({FEAT_DIR})"

# EDIT (relativi a code/distillation, o assoluti):
TEACHER_CKPT = '../../runs/run133/tssi133_gcn_best.pt'   # teacher 41.75
DATA_133     = '../../dataset/phoenix2014t_133kp'        # cartella coi Phoenix-2014T.*

if os.path.exists(_train_pkl):
    print('OK — feature presenti in', FEAT_DIR)
else:
    print('feature assenti → estraggo (~15-30 min)...')
    assert os.path.exists(TEACHER_CKPT), 'checkpoint non trovato: ' + TEACHER_CKPT
    os.environ['TEACHER_CKPT']  = os.path.abspath(TEACHER_CKPT)
    os.environ['MSKA_DATA_DIR'] = os.path.abspath(DATA_133)
    get_ipython().system('python extract_skeleton_feats.py')
    assert os.path.exists(_train_pkl), 'estrazione fallita, manca ' + _train_pkl

# PROVENIENZA: da quale .pt vengono le feature (se estratte con l'estrattore aggiornato)
_src = os.path.join(FEAT_DIR, '_source.txt')
print('provenienza:\n' + (open(_src).read() if os.path.exists(_src)
      else '(no _source.txt — features extracted before tracking; check the .pt manually)'))
# Out:
# OK — feature presenti in ../../dataset/features/skeleton_feats_133
# provenienza:
# (nessun _source.txt — feature estratte prima del tracking; verifica il .pt a mano)

# %%
# Sanity checks: data and teacher features present, config genuinely from-scratch.
BASE_CFG = 'warm_start_fd_cmkd.yaml'
assert os.path.exists(BASE_CFG), 'missing config: ' + BASE_CFG

cfg = yaml.safe_load(open(BASE_CFG))
dc = cfg['training']['distillation']

i3d = os.path.join(cfg['data']['data_path'], cfg['data']['train'])
assert os.path.exists(i3d), 'missing I3D features: ' + i3d

tfp = os.path.join(dc['teacher_feats_dir'], 'train.pkl')
assert os.path.exists(tfp), 'missing teacher features: ' + tfp
_t = load_teacher_feats(tfp)

assert 'load_model' in cfg['training'], 'a warm-start run must load the baseline checkpoint'
print('i3d train features : OK')
print('teacher features   : %d videos, dim %d' % (len(_t), next(iter(_t.values())).shape[1]))
print('warm-start         : loads', cfg['training']['load_model'])
print('distill warmup     : %d steps (0 = off for warm-start)' % dc['distill_warmup_steps'])
# Out:
# i3d train features : OK
# teacher features   : 7096 videos, dim 512
# warm-start         : loads ../../dataset/checkpoints/sign_sample/best.ckpt
# distill warmup     : 0 steps (0 = off for warm-start)

# %%
# Point the config at RUN_DIR, honour OVERWRITE, write the resolved config there.
# The committed warm_start_fd_cmkd.yaml is never modified.
# RUN_DIR is a container. The trainer writes into RUN_DIR/final, which it must
# be free to create fresh: make_model_dir refuses a directory that already
# exists. Writing the config into RUN_DIR (not into MODEL_DIR) keeps them apart.
MODEL_DIR = os.path.join(RUN_DIR, 'final')
cfg['training']['model_dir'] = MODEL_DIR
cfg['training']['overwrite'] = OVERWRITE

os.makedirs(RUN_DIR, exist_ok=True)
ACTIVE_CFG = os.path.join(RUN_DIR, 'warm_start_fd_cmkd.yaml')
with open(ACTIVE_CFG, 'w') as f:
    yaml.safe_dump(cfg, f, sort_keys=False)

tr = cfg['training']
print('active config ->', ACTIVE_CFG)
print('lr=%.3e  wd=%.3e  batch=%d  patience=%d' % (tr['learning_rate'], tr['weight_decay'], tr['batch_size'], tr['early_stopping_patience']))
print('lambda_feat=%.3f  lambda_align=%.3f  w_high=%.3f  warmup=%d' % (dc['lambda_feat'], dc['lambda_align'], dc['high_w'], dc['distill_warmup_steps']))
# Out:
# active config -> ../../runs/forward_warm_133_006/warm_start_fd_cmkd.yaml
# lr=8.182e-05  wd=3.000e-03  batch=32  patience=10
# lambda_feat=0.161  lambda_align=0.150  w_high=0.292  warmup=0

# %% [markdown]
# ## Optional: matched learning-rate search
#
# The baseline was selected over a small Optuna search. For the comparison to be fair,
# the from-scratch distilled arm deserves a search of the **same budget** over the
# **same learning-rate range**. Turn it on to run it; each trial writes to a temporary
# directory under `RUN_DIR`, and the best learning rate is kept.
#
# Leave it off (`USE_OPTUNA = False`) to train a single run at the baseline learning
# rate -- a quick check that the pipeline works, but not, on its own, evidence.

# %%
import copy, shutil, gc

USE_OPTUNA    = False   # True re-runs the matched search (hours)
OPTUNA_TRIALS = 6       # match the baseline budget
LR_RANGE      = (1.5e-4, 6e-4)   # a neighbourhood of the baseline 3.12e-4

if USE_OPTUNA and DO_TRAIN:
    import torch
    try:
        import optuna
    except ImportError:
        import subprocess
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'optuna'])
        import optuna
    optuna.logging.set_verbosity(optuna.logging.WARNING)

    _log = []
    def _objective(trial):
        lr = trial.suggest_float('learning_rate', LR_RANGE[0], LR_RANGE[1], log=True)
        ct = copy.deepcopy(cfg)
        ct['training']['learning_rate'] = float(lr)
        td = os.path.join(RUN_DIR, 'optuna', 'trial_%02d' % trial.number)
        ct['training']['model_dir'] = td
        ct['training']['overwrite'] = True
        # config beside the trial dir, not inside: make_model_dir wipes the
        # dir (overwrite=True) and would delete a config written into it.
        os.makedirs(os.path.dirname(td), exist_ok=True)
        cf = td + '.yaml'
        with open(cf, 'w') as f:
            yaml.safe_dump(ct, f, sort_keys=False)
        train_fd_cmkd(cf)
        wers = []
        vf = os.path.join(ct['training']['model_dir'], 'validations.txt')
        if os.path.exists(vf):
            for line in open(vf):
                toks = line.replace(':', ' ').split()
                if 'WER' in toks:
                    try:
                        wers.append(float(toks[toks.index('WER') + 1]))
                    except (ValueError, IndexError):
                        pass
        best = min(wers) if wers else 100.0
        _log.append((trial.number, lr, best))
        print('  trial %d: lr=%.3e -> dev WER %.2f' % (trial.number, lr, best))
        shutil.rmtree(td, ignore_errors=True)
        if os.path.exists(cf):
            os.remove(cf)
        gc.collect(); torch.cuda.empty_cache()
        return best

    study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(_objective, n_trials=OPTUNA_TRIALS)
    print('best lr:', study.best_params, '-> dev WER', round(study.best_value, 2))
    cfg['training']['learning_rate'] = float(study.best_params['learning_rate'])
    with open(ACTIVE_CFG, 'w') as f:
        yaml.safe_dump(cfg, f, sort_keys=False)
    print('ACTIVE_CFG updated with the searched learning rate.')
else:
    print('Optuna search disabled (or DO_TRAIN=False) -- using the config lr.')
# Out:
# Optuna search disabled (or DO_TRAIN=False) -- using the config lr.

# %%
import torch
# Questo ambiente ha cuDNN difettoso (CUDNN_STATUS_NOT_INITIALIZED su Conv1d/LSTM):
# disattivalo per tutto il kernel (i layer usano il kernel CUDA nativo).
torch.backends.cudnn.enabled = False

# %%
# Train from scratch. This is the long cell.
if DO_TRAIN:
    train_fd_cmkd(ACTIVE_CFG)
else:
    print('DO_TRAIN = False -> skipping training. Set it True to run from scratch.')
# Out:
# 2026-07-17 16:33:57,987 Hello! This is SL-CAT.
# 2026-07-17 16:33:57,990 Total params: 3,757,577
# 2026-07-17 16:33:57,990 Trainable parameters: ['encoder.layer_norm.bias', 'encoder.layer_norm.weight', 'encoder.layers.0.FF2.module.layer_norm.bias', 'encoder.layers.0.FF2.module.layer_norm.weight', 'encoder.layers.0.FF2.module.pwff_layer.0.bias', 'encoder.layers.0.FF2.module.pwff_layer.0.weight', 'encoder.layers.0.FF2.module.pwff_layer.3.bias', 'encoder.layers.0.FF2.module.pwff_layer.3.weight', 'encoder.layers.0.att.module.attention.attn_net.bias', 'encoder.layers.0.att.module.attention.attn_net.weight', 'encoder.layers.0.att.module.attention.k_proj.bias', 'encoder.layers.0.att.module.attention.k_proj.weight', 'encoder.layers.0.att.module.attention.offset_net.0.bias', 'encoder.layers.0.att.module.attention.offset_net.0.weight', 'encoder.layers.0.att.module.attention.offset_net.2.bias', 'encoder.layers.0.att.module.attention.offset_net.2.weight', 'encoder.layers.0.att.module.attention.out_proj.bias', 'encoder.layers.0.att.module.attention.out_proj.weight', 'encoder.layers.0.att.module.attention.q_proj.bias', 'encoder.layers.0.att.module.attention.q_proj.weight', 'encoder.layers.0.att.module.attention.v_proj.bias', 'encoder.layers.0.att.module.attention.v_proj.weight', 'encoder.layers.0.att.module.layer_norm.bias', 'encoder.layers.0.att.module.layer_norm.weight', 'encoder.layers.0.convMod.module.dep1.conv.weight', 'encoder.layers.0.convMod.module.layerNorm.bias', 'encoder.layers.0.convMod.module.layerNorm.weight', 'encoder.layers.0.convMod.module.layerNorm2.bias', 'encoder.layers.0.convMod.module.layerNorm2.weight', 'encoder.layers.0.convMod.module.point1.conv.bias', 'encoder.layers.0.convMod.module.point1.conv.weight', 'encoder.layers.0.convMod.module.point2.conv.bias', 'encoder.layers.0.convMod.module.point2.conv.weight', 'encoder.layers.0.layerNORM.bias', 'encoder.layers.0.layerNORM.weight', 'encoder.layers.1.FF2.module.layer_norm.bias', 'encoder.layers.1.FF2.module.layer_norm.weight', 'encoder.layers.1.FF2.module.pwff_layer.0.bias', 'encoder.layers.1.FF2.module.pwff_layer.0.weight', 'encoder.layers.1.FF2.module.pwff_layer.3.bias', 'encoder.layers.1.FF2.module.pwff_layer.3.weight', 'encoder.layers.1.att.module.attention.attn_net.bias', 'encoder.layers.1.att.module.attention.attn_net.weight', 'encoder.layers.1.att.module.attention.k_proj.bias', 'encoder.layers.1.att.module.attention.k_proj.weight', 'encoder.layers.1.att.module.attention.offset_net.0.bias', 'encoder.layers.1.att.module.attention.offset_net.0.weight', 'encoder.layers.1.att.module.attention.offset_net.2.bias', 'encoder.layers.1.att.module.attention.offset_net.2.weight', 'encoder.layers.1.att.module.attention.out_proj.bias', 'encoder.layers.1.att.module.attention.out_proj.weight', 'encoder.layers.1.att.module.attention.q_proj.bias', 'encoder.layers.1.att.module.attention.q_proj.weight', 'encoder.layers.1.att.module.attention.v_proj.bias', 'encoder.layers.1.att.module.attention.v_proj.weight', 'encoder.layers.1.att.module.layer_norm.bias', 'encoder.layers.1.att.module.layer_norm.weight', 'encoder.layers.1.convMod.module.dep1.conv.weight', 'encoder.layers.1.convMod.module.layerNorm.bias', 'encoder.layers.1.convMod.module.layerNorm.weight', 'encoder.layers.1.convMod.module.layerNorm2.bias', 'encoder.layers.1.convMod.module.layerNorm2.weight', 'encoder.layers.1.convMod.module.point1.conv.bias', 'encoder.layers.1.convMod.module.point1.conv.weight', 'encoder.layers.1.convMod.module.point2.conv.bias', 'encoder.layers.1.convMod.module.point2.conv.weight', 'encoder.layers.1.layerNORM.bias', 'encoder.layers.1.layerNORM.weight', 'encoder.layers.2.FF2.module.layer_norm.bias', 'encoder.layers.2.FF2.module.layer_norm.weight', 'encoder.layers.2.FF2.module.pwff_layer.0.bias', 'encoder.layers.2.FF2.module.pwff_layer.0.weight', 'encoder.layers.2.FF2.module.pwff_layer.3.bias', 'encoder.layers.2.FF2.module.pwff_layer.3.weight', 'encoder.layers.2.att.module.attention.attn_net.bias', 'encoder.layers.2.att.module.attention.attn_net.weight', 'encoder.layers.2.att.module.attention.k_proj ...
# ================================
# COPE:  False
# ================================
# [builders] SophiaG unavailable, falling back to Adam
# /home/ebufi/venv/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 2026-07-17 16:33:58,696 Loading model from ../../dataset/checkpoints/sign_sample/best.ckpt
# 2026-07-17 16:33:58,753 Reset optimizer.
# 2026-07-17 16:33:58,753 Reset scheduler.
# 2026-07-17 16:33:58,754 Reset tracking of the best checkpoint.
# 2026-07-17 16:34:04,027 FD-CMKD ON | student_dim=256 teacher_dim=512 shared_vocab=1021 | lambda_feat=0.161 low_w=1.00 high_w=0.29 lambda_align=0.150 | feats=7096
# 2026-07-17 16:34:04,028 Data set sizes:
# 	train 7094,
# 	valid 519,
# 	test 642
# 2026-07-17 16:34:04,029 First training example:
# 	[GLS] JETZT WETTER MORGEN DONNERSTAG ZWOELF FEBRUAR
# 	[TXT] und nun die wettervorhersage für morgen donnerstag den zwölften august
# 2026-07-17 16:34:04,029 First 10 words (gls): (0) <si> (1) <unk> (2) <pad> (3) REGEN (4) REGION (5) IX (6) KOMMEN (7) MORGEN (8) NORD (9) SONNE
# 2026-07-17 16:34:04,030 First 10 words (txt): (0) <unk> (1) <pad> (2) <s> (3) </s> (4) und (5) im (6) es (7) der (8) am (9) in
# 2026-07-17 16:34:04,030 Number of unique glosses (types): 1087
# 2026-07-17 16:34:04,030 Number of unique words (types): 2888
# 2026-07-17 16:34:04,033 EPOCH 1
# 2026-07-17 16:34:12,306 [Epoch: 001 Step: 00013300] Batch Recognition Loss:   1.514597 => Gls Tokens per Sec:     3009 || Lr: 0.000082
# 2026-07-17 16:34:25,453 Hooray! New best validation result [eval_metric]!
# 2026-07-17 16:34:25,454 Saving new checkpoint.
# 2026-07-17 16:34:25,515 Validation result at epoch   1, step    13300: duration: 13.2081s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.40008	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.39	(DEL: 16.73,	INS: 2.16,	SUB: 21.50)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:34:25,515 Logging Recognition and Translation Outputs
# 2026-07-17 16:34:25,516 ========================================================================================================================
# 2026-07-17 16:34:25,516 Logging Sequence: 10March_2011_Thursday_heute-51
# 2026-07-17 16:34:25,517 	Gloss Reference :	SUEDWEST KOMMEN WARM MORGEN SCHON FRANKREICH REGION FUENFZEHN BIS ZWANZIG GRAD WOCHENENDE KOMMEN WARM
# 2026-07-17 16:34:25,517 	Gloss Hypothesis:	SUEDWEST ****** WARM ****** SCHON ********** LAND   VIERZEHN  BIS ZWANZIG GRAD WOCHENENDE KOMMEN WARM
# 2026-07-17 16:34:25,518 	Gloss Alignment :	         D           D            D          S      S
# 2026-07-17 16:34:25,518 ========================================================================================================================
# 2026-07-17 16:34:25,518 Logging Sequence: 28November_2011_Monday_heute-1587
# 2026-07-17 16:34:25,519 	Gloss Reference :	AUCH MORGEN WETTER SUPER negHABEN FUENF GRAD NORDOST MILD WO   SUEDWEST
# 2026-07-17 16:34:25,519 	Gloss Hypothesis:	**** MORGEN WETTER ***** negHABEN FUENF GRAD ******* **** NORD TEIL
# 2026-07-17 16:34:25,519 	Gloss Alignment :	D                  D                         D       D    S    S
# 2026-07-17 16:34:25,519 ========================================================================================================================
# 2026-07-17 16:34:25,520 Logging Sequence: 07April_2010_Wednesday_heute-1631
# 2026-07-17 16:34:25,520 	Gloss Reference :	FREUNDLICH BLEIBEN REGION SUED BISSCHEN SCHAUER
# 2026-07-17 16:34:25,521 	Gloss Hypothesis:	ABER       BLEIBEN OST    SUED BISSCHEN SCHAUER
# 2026-07-17 16:34:25,521 	Gloss Alignment :	S                  S
# 2026-07-17 16:34:25,521 ========================================================================================================================
# 2026-07-17 16:34:25,521 Logging Sequence: 01July_2011_Friday_tagesschau-2765
# 2026-07-17 16:34:25,522 	Gloss Reference :	HEUTE NACHT ******** DREIZEHN NORD   VIER    BERG
# 2026-07-17 16:34:25,522 	Gloss Hypothesis:	HEUTE NACHT ACHTZEHN OST      REGION ZWANZIG ALPEN
# 2026-07-17 16:34:25,523 	Gloss Alignment :	            I        S        S      S       S
# 2026-07-17 16:34:25,523 ========================================================================================================================
# 2026-07-17 16:34:25,523 Logging Sequence: 19March_2011_Saturday_tagesschau-4690
# 2026-07-17 16:34:25,524 	Gloss Reference :	MORGEN FRUEH VERSCHWINDEN LANGSAM SCHNELL NORDOST BISSCHEN WOLKE BLEIBEN TROCKEN
# 2026-07-17 16:34:25,524 	Gloss Hypothesis:	MORGEN ***** VERSCHWINDEN LANGSAM ******* KALT    BISSCHEN ***** BLEIBEN OST
# 2026-07-17 16:34:25,524 	Gloss Alignment :	       D                          D       S                D             S
# 2026-07-17 16:34:25,525 ========================================================================================================================
# 2026-07-17 16:34:25,525 Logging Sequence: 24January_2010_Sunday_tagesschau-8710
# 2026-07-17 16:34:25,525 	Gloss Reference :	SUED SCHWACH WEHEN IX MAESSIG WEHEN
# 2026-07-17 16:34:25,525 	Gloss Hypothesis:	SUED SCHWACH WEHEN IX MAESSIG WEHEN
# 2026-07-17 16:34:25,526 	Gloss Alignment :
# 2026-07-17 16:34:25,526 ========================================================================================================================
# 2026-07-17 16:34:33,113 [Epoch: 001 Step: 00013400] Batch Recognition Loss:   1.133737 => Gls Tokens per Sec:     3282 || Lr: 0.000082
# 2026-07-17 16:34:46,441 Hooray! New best validation result [eval_metric]!
# 2026-07-17 16:34:46,443 Saving new checkpoint.
# 2026-07-17 16:34:46,508 Validation result at epoch   1, step    13400: duration: 13.3943s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.77141	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 39.83	(DEL: 14.33,	INS: 2.85,	SUB: 22.65)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:34:46,508 Logging Recognition and Translation Outputs
# 2026-07-17 16:34:46,509 ========================================================================================================================
# 2026-07-17 16:34:46,509 Logging Sequence: 24November_2011_Thursday_heute-222
# 2026-07-17 16:34:46,510 	Gloss Reference :	NORD NUR  WOLKE FROST SUED
# 2026-07-17 16:34:46,510 	Gloss Hypothesis:	NORD AUCH WOLKE FROST SUED
# 2026-07-17 16:34:46,510 	Gloss Alignment :	     S
# 2026-07-17 16:34:46,511 ========================================================================================================================
# 2026-07-17 16:34:46,511 Logging Sequence: 14October_2009_Wednesday_tagesschau-529
# 2026-07-17 16:34:46,511 	Gloss Reference :	BESONDERS NORDWEST WIND STARK
# 2026-07-17 16:34:46,511 	Gloss Hypothesis:	BESONDERS NORDWEST WIND STARK
# 2026-07-17 16:34:46,512 	Gloss Alignment :
# 2026-07-17 16:34:46,512 ========================================================================================================================
# 2026-07-17 16:34:46,513 Logging Sequence: 17October_2009_Saturday_tagesschau-2127
# 2026-07-17 16:34:46,513 	Gloss Reference :	TIEF REGION SCHWACH MORGEN SOLL EINFLUSS OST REGION SUED
# 2026-07-17 16:34:46,514 	Gloss Hypothesis:	TIEF MEHR   SCHWACH MORGEN **** FLUSS    OST ****** SUED
# 2026-07-17 16:34:46,514 	Gloss Alignment :	     S                     D    S            D
# 2026-07-17 16:34:46,514 ========================================================================================================================
# 2026-07-17 16:34:46,514 Logging Sequence: 17October_2009_Saturday_tagesschau-2139
# 2026-07-17 16:34:46,515 	Gloss Reference :	NEBEL KUEHL
# 2026-07-17 16:34:46,515 	Gloss Hypothesis:	NEBEL ENORM
# 2026-07-17 16:34:46,516 	Gloss Alignment :	      S
# 2026-07-17 16:34:46,516 ========================================================================================================================
# 2026-07-17 16:34:46,516 Logging Sequence: 10August_2011_Wednesday_tagesschau-6303
# 2026-07-17 16:34:46,516 	Gloss Reference :	IMVERLAUF IMVERLAUF TEMPERATUR REGION
# 2026-07-17 16:34:46,517 	Gloss Hypothesis:	********* IMVERLAUF TEMPERATUR ******
# 2026-07-17 16:34:46,517 	Gloss Alignment :	D                              D
# 2026-07-17 16:34:46,518 ========================================================================================================================
# 2026-07-17 16:34:46,518 Logging Sequence: 09April_2010_Friday_tagesschau-7623
# 2026-07-17 16:34:46,518 	Gloss Reference :	JETZT WETTER MORGEN SAMSTAG ZEHNTE APRIL WIEAUSSEHEN ZEIGENBILDSCHIRM
# 2026-07-17 16:34:46,518 	Gloss Hypothesis:	JETZT WETTER MORGEN ******* ****** APRIL WIEAUSSEHEN ****************
# 2026-07-17 16:34:46,519 	Gloss Alignment :	                    D       D                        D
# 2026-07-17 16:34:46,519 ========================================================================================================================
# 2026-07-17 16:34:48,270 Epoch   1: Total Training Recognition Loss 297.20  Total Training Translation Loss -1.00
# 2026-07-17 16:34:48,271 EPOCH 2
# 2026-07-17 16:34:54,235 [Epoch: 002 Step: 00013500] Batch Recognition Loss:   1.569153 => Gls Tokens per Sec:     3277 || Lr: 0.000082
# 2026-07-17 16:35:07,408 Validation result at epoch   2, step    13500: duration: 13.1721s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.36379	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 41.17	(DEL: 17.42,	INS: 2.13,	SUB: 21.61)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:35:07,409 Logging Recognition and Translation Outputs
# 2026-07-17 16:35:07,409 ========================================================================================================================
# 2026-07-17 16:35:07,410 Logging Sequence: 15December_2010_Wednesday_tagesschau-40
# 2026-07-17 16:35:07,410 	Gloss Reference :	DANN STARK    SCHNEE SCHNEIEN KOMMEN
# 2026-07-17 16:35:07,410 	Gloss Hypothesis:	**** MEISTENS SCHNEE SCHNEIEN KOMMEN
# 2026-07-17 16:35:07,411 	Gloss Alignment :	D    S
# 2026-07-17 16:35:07,411 ========================================================================================================================
# 2026-07-17 16:35:07,412 Logging Sequence: 01December_2011_Thursday_heute-3061
# 2026-07-17 16:35:07,412 	Gloss Reference :	ABER  DAZWISCHEN REGION MILD NEUN BIS VIERZEHN GRAD
# 2026-07-17 16:35:07,412 	Gloss Hypothesis:	MITTE REGION     IX     MILD NEUN BIS VIERZEHN GRAD
# 2026-07-17 16:35:07,413 	Gloss Alignment :	S     S          S
# 2026-07-17 16:35:07,413 ========================================================================================================================
# 2026-07-17 16:35:07,413 Logging Sequence: 20February_2011_Sunday_tagesschau-3166
# 2026-07-17 16:35:07,414 	Gloss Reference :	AMTAG REGION SCHNEE FLUSS REGEN
# 2026-07-17 16:35:07,414 	Gloss Hypothesis:	***** TAG    BERG   FLUSS *****
# 2026-07-17 16:35:07,415 	Gloss Alignment :	D     S      S            D
# 2026-07-17 16:35:07,415 ========================================================================================================================
# 2026-07-17 16:35:07,415 Logging Sequence: 20June_2011_Monday_heute-6514
# 2026-07-17 16:35:07,416 	Gloss Reference :	DANN WETTER WECHSELHAFT
# 2026-07-17 16:35:07,416 	Gloss Hypothesis:	**** WETTER WECHSELHAFT
# 2026-07-17 16:35:07,416 	Gloss Alignment :	D
# 2026-07-17 16:35:07,417 ========================================================================================================================
# 2026-07-17 16:35:07,417 Logging Sequence: 10November_2009_Tuesday_tagesschau-7250
# 2026-07-17 16:35:07,418 	Gloss Reference :	DONNERSTAG NEBEL AUFLOESEN WOLKE BEWOELKT HABEN2
# 2026-07-17 16:35:07,418 	Gloss Hypothesis:	DONNERSTAG ***** KOMMEN    WOLKE ******** ******
# 2026-07-17 16:35:07,418 	Gloss Alignment :	           D     S               D        D
# 2026-07-17 16:35:07,419 ========================================================================================================================
# 2026-07-17 16:35:07,419 Logging Sequence: 24January_2013_Thursday_heute-7254
# 2026-07-17 16:35:07,419 	Gloss Reference :	ENDLICH SONNE ABER DEUTSCH KAUM
# 2026-07-17 16:35:07,420 	Gloss Hypothesis:	TEIL    SONNE ABER ******* BISSCHEN
# 2026-07-17 16:35:07,420 	Gloss Alignment :	S                  D       S
# 2026-07-17 16:35:07,420 ========================================================================================================================
# 2026-07-17 16:35:15,100 [Epoch: 002 Step: 00013600] Batch Recognition Loss:   1.130624 => Gls Tokens per Sec:     3247 || Lr: 0.000082
# 2026-07-17 16:35:28,376 Validation result at epoch   2, step    13600: duration: 13.2753s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.49446	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 39.89	(DEL: 15.98,	INS: 2.37,	SUB: 21.53)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:35:28,377 Logging Recognition and Translation Outputs
# 2026-07-17 16:35:28,377 ========================================================================================================================
# 2026-07-17 16:35:28,378 Logging Sequence: 07October_2012_Sunday_tagesschau-3026
# 2026-07-17 16:35:28,378 	Gloss Reference :	TAG KLAR STERN SEHEN KOENNEN FROST
# 2026-07-17 16:35:28,379 	Gloss Hypothesis:	TAG KLAR ***** SEHEN ******* FROST
# 2026-07-17 16:35:28,379 	Gloss Alignment :	         D           D
# 2026-07-17 16:35:28,380 ========================================================================================================================
# 2026-07-17 16:35:28,380 Logging Sequence: 23April_2010_Friday_tagesschau-3667
# 2026-07-17 16:35:28,380 	Gloss Reference :	***** NACHT MINUS DREI BIS PLUS VIER NORD PLUS FUENF IX
# 2026-07-17 16:35:28,381 	Gloss Hypothesis:	HEUTE NACHT MINUS DREI BIS PLUS VIER NORD PLUS FUENF **
# 2026-07-17 16:35:28,381 	Gloss Alignment :	I                                                    D
# 2026-07-17 16:35:28,381 ========================================================================================================================
# 2026-07-17 16:35:28,382 Logging Sequence: 30September_2012_Sunday_tagesschau-4038
# 2026-07-17 16:35:28,382 	Gloss Reference :	DONNERSTAG DEUTSCH LAND WECHSELHAFT UEBERWIEGEND   REGEN MOEGLICH STARK  WIND
# 2026-07-17 16:35:28,382 	Gloss Hypothesis:	DONNERSTAG ******* LAND WECHSELHAFT HAUPTSAECHLICH REGEN KOENNEN  FRISCH WIND
# 2026-07-17 16:35:28,382 	Gloss Alignment :	           D                        S                    S        S
# 2026-07-17 16:35:28,383 ========================================================================================================================
# 2026-07-17 16:35:28,383 Logging Sequence: 10December_2011_Saturday_tagesschau-5420
# 2026-07-17 16:35:28,384 	Gloss Reference :	AB MONTAG INKOMMEND WETTER WECHSELHAFT WIND
# 2026-07-17 16:35:28,384 	Gloss Hypothesis:	** MONTAG ********* WETTER WECHSELHAFT ****
# 2026-07-17 16:35:28,384 	Gloss Alignment :	D         D                            D
# 2026-07-17 16:35:28,384 ========================================================================================================================
# 2026-07-17 16:35:28,385 Logging Sequence: 28May_2010_Friday_tagesschau-7496
# 2026-07-17 16:35:28,385 	Gloss Reference :	HOCH KOMMEN OST KOMMEN ESBEDEUTET MORGEN FREUNDLICH WETTER
# 2026-07-17 16:35:28,385 	Gloss Hypothesis:	LUFT KOMMEN OST REGION DANN       MORGEN FREUNDLICH WETTER
# 2026-07-17 16:35:28,386 	Gloss Alignment :	S               S      S
# 2026-07-17 16:35:28,386 ========================================================================================================================
# 2026-07-17 16:35:28,386 Logging Sequence: 29June_2010_Tuesday_tagesschau-7705
# 2026-07-17 16:35:28,387 	Gloss Reference :	HEUTE NACHT TEMPERATUR ELF  BIS ACHTZEHN GRAD
# 2026-07-17 16:35:28,387 	Gloss Hypothesis:	HEUTE NACHT TEMPERATUR EINS BIS ACHTZEHN GRAD
# 2026-07-17 16:35:28,387 	Gloss Alignment :	                       S
# 2026-07-17 16:35:28,388 ========================================================================================================================
# 2026-07-17 16:35:31,713 Epoch   2: Total Training Recognition Loss 288.13  Total Training Translation Loss -1.00
# 2026-07-17 16:35:31,714 EPOCH 3
# 2026-07-17 16:35:36,043 [Epoch: 003 Step: 00013700] Batch Recognition Loss:   1.182138 => Gls Tokens per Sec:     3272 || Lr: 0.000082
# 2026-07-17 16:35:49,274 Validation result at epoch   3, step    13700: duration: 13.2301s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.38980	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.31	(DEL: 17.37,	INS: 1.87,	SUB: 21.08)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:35:49,274 Logging Recognition and Translation Outputs
# 2026-07-17 16:35:49,275 ========================================================================================================================
# 2026-07-17 16:35:49,275 Logging Sequence: 22November_2010_Monday_heute-279
# 2026-07-17 16:35:49,276 	Gloss Reference :	IX KOENNEN GEFAHR GLATT BESONDERS MITTE REGION SUED DANN KALT
# 2026-07-17 16:35:49,276 	Gloss Hypothesis:	IX KOENNEN ****** WOLKE BESONDERS ***** REGION SUED **** KALT
# 2026-07-17 16:35:49,277 	Gloss Alignment :	           D      S               D                 D
# 2026-07-17 16:35:49,277 ========================================================================================================================
# 2026-07-17 16:35:49,278 Logging Sequence: 22January_2010_Friday_tagesschau-907
# 2026-07-17 16:35:49,278 	Gloss Reference :	TAG VIEL WOLKE NEBEL BLEIBEN TROCKEN IX SONNE MOEGLICH
# 2026-07-17 16:35:49,278 	Gloss Hypothesis:	TAG VIEL WOLKE NEBEL ******* TROCKEN IX SONNE MOEGLICH
# 2026-07-17 16:35:49,279 	Gloss Alignment :	                     D
# 2026-07-17 16:35:49,279 ========================================================================================================================
# 2026-07-17 16:35:49,279 Logging Sequence: 20October_2009_Tuesday_tagesschau-3595
# 2026-07-17 16:35:49,280 	Gloss Reference :	WIND WEHEN MAESSIG WEHEN
# 2026-07-17 16:35:49,280 	Gloss Hypothesis:	WIND WEHEN MAESSIG *****
# 2026-07-17 16:35:49,281 	Gloss Alignment :	                   D
# 2026-07-17 16:35:49,281 ========================================================================================================================
# 2026-07-17 16:35:49,281 Logging Sequence: 10August_2011_Wednesday_tagesschau-6303
# 2026-07-17 16:35:49,282 	Gloss Reference :	IMVERLAUF IMVERLAUF TEMPERATUR REGION
# 2026-07-17 16:35:49,282 	Gloss Hypothesis:	********* IMVERLAUF TEMPERATUR ******
# 2026-07-17 16:35:49,283 	Gloss Alignment :	D                              D
# 2026-07-17 16:35:49,283 ========================================================================================================================
# 2026-07-17 16:35:49,283 Logging Sequence: 12November_2009_Thursday_tagesschau-6770
# 2026-07-17 16:35:49,283 	Gloss Reference :	NORD MORGEN BEWOELKT REGION REGEN
# 2026-07-17 16:35:49,284 	Gloss Hypothesis:	NORD MORGEN WOLKE    REGION REGEN
# 2026-07-17 16:35:49,284 	Gloss Alignment :	            S
# 2026-07-17 16:35:49,285 ========================================================================================================================
# 2026-07-17 16:35:49,285 Logging Sequence: 15July_2011_Friday_tagesschau-8726
# 2026-07-17 16:35:49,285 	Gloss Reference :	IX MORGEN NEUNZEHN   GRAD REGION SIEBEN ZWANZIG GRAD
# 2026-07-17 16:35:49,286 	Gloss Hypothesis:	IX MORGEN DONNERSTAG GRAD REGION SIEBEN ZWANZIG GRAD
# 2026-07-17 16:35:49,286 	Gloss Alignment :	          S
# 2026-07-17 16:35:49,286 ========================================================================================================================
# 2026-07-17 16:35:56,996 [Epoch: 003 Step: 00013800] Batch Recognition Loss:   1.251546 => Gls Tokens per Sec:     3223 || Lr: 0.000082
# 2026-07-17 16:36:10,217 Validation result at epoch   3, step    13800: duration: 13.2205s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.45787	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.45	(DEL: 17.08,	INS: 2.16,	SUB: 21.21)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:36:10,218 Logging Recognition and Translation Outputs
# 2026-07-17 16:36:10,218 ========================================================================================================================
# 2026-07-17 16:36:10,219 Logging Sequence: 25February_2011_Friday_tagesschau-575
# 2026-07-17 16:36:10,219 	Gloss Reference :	DIENSTAG RUHIG TROCKEN WETTER
# 2026-07-17 16:36:10,219 	Gloss Hypothesis:	WENN     RUHIG TROCKEN WETTER
# 2026-07-17 16:36:10,220 	Gloss Alignment :	S
# 2026-07-17 16:36:10,220 ========================================================================================================================
# 2026-07-17 16:36:10,221 Logging Sequence: 27August_2009_Thursday_tagesschau-3285
# 2026-07-17 16:36:10,221 	Gloss Reference :	NORD SCHAUER
# 2026-07-17 16:36:10,221 	Gloss Hypothesis:	**** OST
# 2026-07-17 16:36:10,222 	Gloss Alignment :	D    S
# 2026-07-17 16:36:10,222 ========================================================================================================================
# 2026-07-17 16:36:10,223 Logging Sequence: 24January_2011_Monday_tagesschau-3720
# 2026-07-17 16:36:10,223 	Gloss Reference :	WIND WEHEN FRISCH KOMMEN HOCH   STURM
# 2026-07-17 16:36:10,223 	Gloss Hypothesis:	WIND ***** FRISCH WEHEN  SCHWER STURM
# 2026-07-17 16:36:10,224 	Gloss Alignment :	     D            S      S
# 2026-07-17 16:36:10,224 ========================================================================================================================
# 2026-07-17 16:36:10,224 Logging Sequence: 29September_2011_Thursday_heute-4235
# 2026-07-17 16:36:10,225 	Gloss Reference :	SCHOEN ABEND possEUCH MACHEN GUT possEUCH
# 2026-07-17 16:36:10,225 	Gloss Hypothesis:	SCHOEN ABEND possEUCH ****** GUT possEUCH
# 2026-07-17 16:36:10,226 	Gloss Alignment :	                      D
# 2026-07-17 16:36:10,226 ========================================================================================================================
# 2026-07-17 16:36:10,226 Logging Sequence: 24October_2009_Saturday_tagesschau-4285
# 2026-07-17 16:36:10,227 	Gloss Reference :	**** TAG    DANN WEST FREUNDLICH SONNE DABEI
# 2026-07-17 16:36:10,227 	Gloss Hypothesis:	NORD STUNDE DANN WEST MEHR       SONNE DABEI
# 2026-07-17 16:36:10,228 	Gloss Alignment :	I    S                S
# 2026-07-17 16:36:10,228 ========================================================================================================================
# 2026-07-17 16:36:10,228 Logging Sequence: 24July_2011_Sunday_tagesschau-6621
# 2026-07-17 16:36:10,229 	Gloss Reference :	DARUNTER TAG IMVERLAUF MEHR   WARM
# 2026-07-17 16:36:10,229 	Gloss Hypothesis:	******** TAG ********* MITTAG BLEIBEN
# 2026-07-17 16:36:10,229 	Gloss Alignment :	D            D         S      S
# 2026-07-17 16:36:10,229 ========================================================================================================================
# 2026-07-17 16:36:15,223 Epoch   3: Total Training Recognition Loss 283.23  Total Training Translation Loss -1.00
# 2026-07-17 16:36:15,224 EPOCH 4
# 2026-07-17 16:36:17,845 [Epoch: 004 Step: 00013900] Batch Recognition Loss:   1.182372 => Gls Tokens per Sec:     3212 || Lr: 0.000082
# 2026-07-17 16:36:31,043 Validation result at epoch   4, step    13900: duration: 13.1970s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.30849	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 39.86	(DEL: 16.41,	INS: 2.11,	SUB: 21.34)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:36:31,044 Logging Recognition and Translation Outputs
# 2026-07-17 16:36:31,044 ========================================================================================================================
# 2026-07-17 16:36:31,044 Logging Sequence: 04April_2011_Monday_heute-965
# 2026-07-17 16:36:31,045 	Gloss Reference :	MORGEN MEHR WARM IX ALS HEUTE
# 2026-07-17 16:36:31,045 	Gloss Hypothesis:	MORGEN MEHR WARM ** *** JETZT
# 2026-07-17 16:36:31,046 	Gloss Alignment :	                 D  D   S
# 2026-07-17 16:36:31,046 ========================================================================================================================
# 2026-07-17 16:36:31,047 Logging Sequence: 29October_2009_Thursday_tagesschau-1011
# 2026-07-17 16:36:31,047 	Gloss Reference :	JETZT WETTER WIEAUSSEHEN MORGEN **** DREISSIG OKTOBER
# 2026-07-17 16:36:31,047 	Gloss Hypothesis:	JETZT WETTER WIEAUSSEHEN MORGEN EINS ZWANZIG  OKTOBER
# 2026-07-17 16:36:31,048 	Gloss Alignment :	                                I    S
# 2026-07-17 16:36:31,048 ========================================================================================================================
# 2026-07-17 16:36:31,048 Logging Sequence: 23July_2011_Saturday_tagesschau-5498
# 2026-07-17 16:36:31,049 	Gloss Reference :	SPAETER REGEN UEBERALL REGION ******
# 2026-07-17 16:36:31,049 	Gloss Hypothesis:	SPAETER MEHR  LEICHT   REGION KOMMEN
# 2026-07-17 16:36:31,050 	Gloss Alignment :	        S     S               I
# 2026-07-17 16:36:31,050 ========================================================================================================================
# 2026-07-17 16:36:31,050 Logging Sequence: 18November_2009_Wednesday_tagesschau-5586
# 2026-07-17 16:36:31,051 	Gloss Reference :	WENN     NEBEL negHABEN FREUNDLICH
# 2026-07-17 16:36:31,051 	Gloss Hypothesis:	BISSCHEN NEBEL KUEHL    FREUNDLICH
# 2026-07-17 16:36:31,051 	Gloss Alignment :	S              S
# 2026-07-17 16:36:31,052 ========================================================================================================================
# 2026-07-17 16:36:31,052 Logging Sequence: 24January_2011_Monday_heute-6980
# 2026-07-17 16:36:31,053 	Gloss Reference :	MORGEN MEISTENS ZWEI BIS SECHS GRAD ABER BAYERN REGION BISSCHEN KALT    MITTE REGION AUCH
# 2026-07-17 16:36:31,053 	Gloss Hypothesis:	MORGEN ******** ZWEI BIS SECHS GRAD AUCH BAYERN REGION ******** KOENNEN MITTE REGION AUCH
# 2026-07-17 16:36:31,053 	Gloss Alignment :	       D                            S                  D        S
# 2026-07-17 16:36:31,054 ========================================================================================================================
# 2026-07-17 16:36:31,054 Logging Sequence: 16July_2011_Saturday_tagesschau-7524
# 2026-07-17 16:36:31,055 	Gloss Reference :	NACHT KOMMEN REGEN STARK OST SUEDOST KLAR SEHEN STERN KOENNEN
# 2026-07-17 16:36:31,055 	Gloss Hypothesis:	WEST  KOMMEN REGEN STARK OST SUEDOST KLAR IX    STERN KOENNEN
# 2026-07-17 16:36:31,055 	Gloss Alignment :	S                                         S
# 2026-07-17 16:36:31,055 ========================================================================================================================
# 2026-07-17 16:36:38,704 [Epoch: 004 Step: 00014000] Batch Recognition Loss:   1.221189 => Gls Tokens per Sec:     3261 || Lr: 0.000082
# 2026-07-17 16:36:51,787 Validation result at epoch   4, step    14000: duration: 13.0821s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.58681	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.18	(DEL: 16.57,	INS: 2.29,	SUB: 21.32)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:36:51,788 Logging Recognition and Translation Outputs
# 2026-07-17 16:36:51,788 ========================================================================================================================
# 2026-07-17 16:36:51,788 Logging Sequence: 09August_2009_Sunday_tagesschau-1179
# 2026-07-17 16:36:51,789 	Gloss Reference :	MORGEN WEST TIEF KOMMEN RICHTUNG OST AUFZIEHEN
# 2026-07-17 16:36:51,789 	Gloss Hypothesis:	MORGEN WEST TIEF KOMMEN ******** OST *********
# 2026-07-17 16:36:51,790 	Gloss Alignment :	                        D            D
# 2026-07-17 16:36:51,790 ========================================================================================================================
# 2026-07-17 16:36:51,790 Logging Sequence: 10August_2010_Tuesday_heute-1455
# 2026-07-17 16:36:51,791 	Gloss Reference :	OST REGION SONNE MEHR WARM MAXIMAL SECHS ZWANZIG SUED MAXIMAL SIEBEN ZWANZIG GRAD
# 2026-07-17 16:36:51,791 	Gloss Hypothesis:	OST REGION SONNE MEHR WARM MAXIMAL ZEHN  ZWANZIG SUED MAXIMAL SIEBEN ZWANZIG ****
# 2026-07-17 16:36:51,792 	Gloss Alignment :	                                   S                                         D
# 2026-07-17 16:36:51,792 ========================================================================================================================
# 2026-07-17 16:36:51,793 Logging Sequence: 12November_2009_Thursday_tagesschau-6771
# 2026-07-17 16:36:51,793 	Gloss Reference :	SUED ******** MEISTENS TROCKEN EINIGE WOLKE NEBEL MAL      SONNE
# 2026-07-17 16:36:51,793 	Gloss Hypothesis:	SUED SUEDWEST MEISTENS TROCKEN VIEL   WOLKE NEBEL MANCHMAL SONNE
# 2026-07-17 16:36:51,794 	Gloss Alignment :	     I                         S                  S
# 2026-07-17 16:36:51,794 ========================================================================================================================
# 2026-07-17 16:36:51,794 Logging Sequence: 13July_2009_Monday_tagesschau-7513
# 2026-07-17 16:36:51,795 	Gloss Reference :	REGION SONNE SCHAUER GEWITTER SUED IX    ENORM HAGEL STARK REGEN STURM
# 2026-07-17 16:36:51,795 	Gloss Hypothesis:	REGION ***** SCHAUER GEWITTER SUED ENORM KUEHL TIEF  STARK REGEN STURM
# 2026-07-17 16:36:51,796 	Gloss Alignment :	       D                           S     S     S
# 2026-07-17 16:36:51,796 ========================================================================================================================
# 2026-07-17 16:36:51,796 Logging Sequence: 13May_2010_Thursday_tagesschau-7916
# 2026-07-17 16:36:51,797 	Gloss Reference :	JETZT WETTER MORGEN FREITAG VIERZEHN MAI
# 2026-07-17 16:36:51,797 	Gloss Hypothesis:	JETZT WETTER ****** FREITAG ******** ***
# 2026-07-17 16:36:51,797 	Gloss Alignment :	             D              D        D
# 2026-07-17 16:36:51,798 ========================================================================================================================
# 2026-07-17 16:36:51,798 Logging Sequence: 27May_2011_Friday_tagesschau-8133
# 2026-07-17 16:36:51,799 	Gloss Reference :	DIENSTAG KOMMEN REGEN KOENNEN GEWITTER UNWETTER REGEN HAGEL KRAEFTIG WIND  KOENNEN
# 2026-07-17 16:36:51,799 	Gloss Hypothesis:	DIENSTAG KOMMEN REGEN KOENNEN WIND     NUR      REGEN ***** ******** STURM KOENNEN
# 2026-07-17 16:36:51,799 	Gloss Alignment :	                              S        S              D     D        S
# 2026-07-17 16:36:51,799 ========================================================================================================================
# 2026-07-17 16:36:58,531 Epoch   4: Total Training Recognition Loss 276.41  Total Training Translation Loss -1.00
# 2026-07-17 16:36:58,532 EPOCH 5
# 2026-07-17 16:36:59,508 [Epoch: 005 Step: 00014100] Batch Recognition Loss:   0.962652 => Gls Tokens per Sec:     3075 || Lr: 0.000082
# 2026-07-17 16:37:12,744 Validation result at epoch   5, step    14100: duration: 13.2356s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.64130	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.96	(DEL: 17.90,	INS: 2.40,	SUB: 20.65)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:37:12,745 Logging Recognition and Translation Outputs
# 2026-07-17 16:37:12,746 ========================================================================================================================
# 2026-07-17 16:37:12,746 Logging Sequence: 30January_2013_Wednesday_tagesschau-477
# 2026-07-17 16:37:12,747 	Gloss Reference :	SONNTAG WAHRSCHEINLICH FREUNDLICH IMVERLAUF WEST SCHNEE SCHNEIEN REGEN
# 2026-07-17 16:37:12,747 	Gloss Hypothesis:	SONNTAG WEHEN          FREUNDLICH IMVERLAUF WEST SCHNEE SCHNEIEN REGEN
# 2026-07-17 16:37:12,748 	Gloss Alignment :	        S
# 2026-07-17 16:37:12,748 ========================================================================================================================
# 2026-07-17 16:37:12,748 Logging Sequence: 23April_2010_Friday_tagesschau-3668
# 2026-07-17 16:37:12,749 	Gloss Reference :	MORGEN ZEHN BIS FUENFZEHN REGION SECHSZEHN BIS DREI ZWANZIG
# 2026-07-17 16:37:12,749 	Gloss Hypothesis:	MORGEN ZEHN BIS FUENFZEHN REGION ********* *** DREI ZWANZIG
# 2026-07-17 16:37:12,750 	Gloss Alignment :	                                 D         D
# 2026-07-17 16:37:12,750 ========================================================================================================================
# 2026-07-17 16:37:12,751 Logging Sequence: 28September_2009_Monday_tagesschau-4680
# 2026-07-17 16:37:12,751 	Gloss Reference :	TAG VIERZEHN NORD REGEN  EINS ZWANZIG FLUSS
# 2026-07-17 16:37:12,752 	Gloss Hypothesis:	TAG ******** NORD SCHNEE EINS ZWANZIG FLUSS
# 2026-07-17 16:37:12,752 	Gloss Alignment :	    D             S
# 2026-07-17 16:37:12,752 ========================================================================================================================
# 2026-07-17 16:37:12,753 Logging Sequence: 29November_2011_Tuesday_tagesschau-5619
# 2026-07-17 16:37:12,753 	Gloss Reference :	NACHT SECHS GRAD SEE MINUS DREI FLUSS
# 2026-07-17 16:37:12,754 	Gloss Hypothesis:	NACHT EINS  GRAD *** MINUS DREI ZWOELF
# 2026-07-17 16:37:12,754 	Gloss Alignment :	      S          D              S
# 2026-07-17 16:37:12,754 ========================================================================================================================
# 2026-07-17 16:37:12,755 Logging Sequence: 19January_2011_Wednesday_tagesschau-7068
# 2026-07-17 16:37:12,755 	Gloss Reference :	JETZT WETTER VORAUS INFORMIEREN MORGEN DONNERSTAG ZWANZIG JANUAR
# 2026-07-17 16:37:12,756 	Gloss Hypothesis:	JETZT WETTER VORAUS *********** MORGEN DONNERSTAG ZWANZIG JANUAR
# 2026-07-17 16:37:12,756 	Gloss Alignment :	                    D
# 2026-07-17 16:37:12,756 ========================================================================================================================
# 2026-07-17 16:37:12,757 Logging Sequence: 27June_2010_Sunday_tagesschau-7386
# 2026-07-17 16:37:12,757 	Gloss Reference :	DIENSTAG MITTWOCH ******** TIEF KOMMEN MOEGLICH REGEN GEWITTER
# 2026-07-17 16:37:12,757 	Gloss Hypothesis:	DIENSTAG MITTWOCH DIENSTAG TIEF KOMMEN MOEGLICH REGEN GEWITTER
# 2026-07-17 16:37:12,758 	Gloss Alignment :	                  I
# 2026-07-17 16:37:12,758 ========================================================================================================================
# 2026-07-17 16:37:20,502 [Epoch: 005 Step: 00014200] Batch Recognition Loss:   0.926893 => Gls Tokens per Sec:     3230 || Lr: 0.000082
# 2026-07-17 16:37:33,799 Validation result at epoch   5, step    14200: duration: 13.2968s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 37.12676	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.55	(DEL: 15.47,	INS: 2.83,	SUB: 22.25)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:37:33,800 Logging Recognition and Translation Outputs
# 2026-07-17 16:37:33,800 ========================================================================================================================
# 2026-07-17 16:37:33,801 Logging Sequence: 06July_2009_Monday_tagesschau-2109
# 2026-07-17 16:37:33,802 	Gloss Reference :	******** MORGEN WERT   EIFEL ACHTZEHN BIS SECHS ZWANZIG LAND
# 2026-07-17 16:37:33,802 	Gloss Hypothesis:	MITTWOCH MORGEN WEITER BERG  ACHTZEHN BIS SECHS ZWANZIG REGION
# 2026-07-17 16:37:33,803 	Gloss Alignment :	I               S      S                                S
# 2026-07-17 16:37:33,803 ========================================================================================================================
# 2026-07-17 16:37:33,803 Logging Sequence: 31May_2011_Tuesday_tagesschau-4294
# 2026-07-17 16:37:33,804 	Gloss Reference :	DEUTSCH  WETTER DIENST WARNUNG
# 2026-07-17 16:37:33,804 	Gloss Hypothesis:	NORDWEST WETTER ANFANG WARNUNG
# 2026-07-17 16:37:33,804 	Gloss Alignment :	S               S
# 2026-07-17 16:37:33,805 ========================================================================================================================
# 2026-07-17 16:37:33,805 Logging Sequence: 28September_2009_Monday_tagesschau-4680
# 2026-07-17 16:37:33,805 	Gloss Reference :	TAG VIERZEHN NORD REGEN  EINS ZWANZIG FLUSS
# 2026-07-17 16:37:33,806 	Gloss Hypothesis:	TAG ******** NORD SCHNEE EINS ZWANZIG FLUSS
# 2026-07-17 16:37:33,806 	Gloss Alignment :	    D             S
# 2026-07-17 16:37:33,806 ========================================================================================================================
# 2026-07-17 16:37:33,807 Logging Sequence: 23September_2009_Wednesday_tagesschau-7593
# 2026-07-17 16:37:33,807 	Gloss Reference :	SONNTAG SCHEINEN ALPEN AUCH SCHAUER MOEGLICH
# 2026-07-17 16:37:33,808 	Gloss Hypothesis:	SONNTAG WOLKE    ALPEN AUCH SCHAUER MOEGLICH
# 2026-07-17 16:37:33,808 	Gloss Alignment :	        S
# 2026-07-17 16:37:33,808 ========================================================================================================================
# 2026-07-17 16:37:33,809 Logging Sequence: 03September_2010_Friday_tagesschau-8423
# 2026-07-17 16:37:33,809 	Gloss Reference :	KUEHL KOMMEN
# 2026-07-17 16:37:33,809 	Gloss Hypothesis:	KUEHL ******
# 2026-07-17 16:37:33,810 	Gloss Alignment :	      D
# 2026-07-17 16:37:33,810 ========================================================================================================================
# 2026-07-17 16:37:33,810 Logging Sequence: 23March_2011_Wednesday_tagesschau-8751
# 2026-07-17 16:37:33,811 	Gloss Reference :	NORDOST WIEDER WOLKE ABER SONST NUR BISSCHEN WOLKE
# 2026-07-17 16:37:33,811 	Gloss Hypothesis:	NORDOST OST    WOLKE **** SONST NUR ******** WEHEN
# 2026-07-17 16:37:33,812 	Gloss Alignment :	        S            D              D        S
# 2026-07-17 16:37:33,812 ========================================================================================================================
# 2026-07-17 16:37:41,405 [Epoch: 005 Step: 00014300] Batch Recognition Loss:   1.341303 => Gls Tokens per Sec:     3269 || Lr: 0.000082
# 2026-07-17 16:37:54,620 Validation result at epoch   5, step    14300: duration: 13.2138s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.96236	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.90	(DEL: 16.33,	INS: 2.51,	SUB: 22.07)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:37:54,621 Logging Recognition and Translation Outputs
# 2026-07-17 16:37:54,621 ========================================================================================================================
# 2026-07-17 16:37:54,621 Logging Sequence: 21August_2011_Sunday_tagesschau-265
# 2026-07-17 16:37:54,622 	Gloss Reference :	MITTE REGION WOLKE MORGEN KOENNEN REGEN GEWITTER
# 2026-07-17 16:37:54,622 	Gloss Hypothesis:	SONST REGION WOLKE MORGEN HEUTE   REGEN GEWITTER
# 2026-07-17 16:37:54,623 	Gloss Alignment :	S                         S
# 2026-07-17 16:37:54,623 ========================================================================================================================
# 2026-07-17 16:37:54,623 Logging Sequence: 04May_2010_Tuesday_heute-453
# 2026-07-17 16:37:54,624 	Gloss Reference :	HOCH NORD SONNE DESHALB GRENZE HOCH TIEF
# 2026-07-17 16:37:54,624 	Gloss Hypothesis:	HOCH NORD SONNE DESHALB ****** HOCH ****
# 2026-07-17 16:37:54,625 	Gloss Alignment :	                        D           D
# 2026-07-17 16:37:54,625 ========================================================================================================================
# 2026-07-17 16:37:54,625 Logging Sequence: 02October_2012_Tuesday_heute-3494
# 2026-07-17 16:37:54,626 	Gloss Reference :	HEUTE NACHT negKAUM NUR NORDWEST BISSCHEN REGEN SONST REGION RUHIG
# 2026-07-17 16:37:54,626 	Gloss Hypothesis:	HEUTE NACHT AUCH    NUR NORDWEST BISSCHEN REGEN SONST REGION *****
# 2026-07-17 16:37:54,627 	Gloss Alignment :	            S                                                D
# 2026-07-17 16:37:54,627 ========================================================================================================================
# 2026-07-17 16:37:54,627 Logging Sequence: 20June_2011_Monday_heute-6514
# 2026-07-17 16:37:54,628 	Gloss Reference :	DANN WETTER WECHSELHAFT
# 2026-07-17 16:37:54,628 	Gloss Hypothesis:	**** WETTER WECHSELHAFT
# 2026-07-17 16:37:54,628 	Gloss Alignment :	D
# 2026-07-17 16:37:54,628 ========================================================================================================================
# 2026-07-17 16:37:54,629 Logging Sequence: 24January_2011_Monday_heute-6984
# 2026-07-17 16:37:54,629 	Gloss Reference :	MITTWOCH SONNE NICHT NUR WEST SCHNEE REGEN MISCHUNG DANN BEISEITE
# 2026-07-17 16:37:54,630 	Gloss Hypothesis:	MITTWOCH SONNE VIER  NUR WEST ****** REGEN REGION   DANN ********
# 2026-07-17 16:37:54,630 	Gloss Alignment :	               S              D            S             D
# 2026-07-17 16:37:54,630 ========================================================================================================================
# 2026-07-17 16:37:54,631 Logging Sequence: 25January_2013_Friday_tagesschau-7815
# 2026-07-17 16:37:54,631 	Gloss Reference :	MORGEN TEIL UEBERWIEGEND WOLKE TEIL SONNE OST UEBERWIEGEND   MEHR SONNE DABEI
# 2026-07-17 16:37:54,631 	Gloss Hypothesis:	****** TEIL ************ WOLKE TEIL SONNE OST HAUPTSAECHLICH MEHR SONNE *****
# 2026-07-17 16:37:54,632 	Gloss Alignment :	D           D                                 S                         D
# 2026-07-17 16:37:54,632 ========================================================================================================================
# 2026-07-17 16:37:55,350 Epoch   5: Total Training Recognition Loss 272.14  Total Training Translation Loss -1.00
# 2026-07-17 16:37:55,413 Periodic checkpoint saved at epoch 5, step 14310 -> ../../runs/forward_warm_133_006/final/resume.ckpt
# 2026-07-17 16:37:55,414 EPOCH 6
# ...
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:41:44,230 Logging Recognition and Translation Outputs
# 2026-07-17 16:41:44,230 ========================================================================================================================
# 2026-07-17 16:41:44,231 Logging Sequence: 29October_2009_Thursday_tagesschau-1011
# 2026-07-17 16:41:44,232 	Gloss Reference :	JETZT WETTER WIEAUSSEHEN MORGEN **** DREISSIG OKTOBER
# 2026-07-17 16:41:44,232 	Gloss Hypothesis:	JETZT WETTER WIEAUSSEHEN MORGEN EINS ZWANZIG  OKTOBER
# 2026-07-17 16:41:44,232 	Gloss Alignment :	                                I    S
# 2026-07-17 16:41:44,233 ========================================================================================================================
# 2026-07-17 16:41:44,233 Logging Sequence: 01March_2011_Tuesday_tagesschau-2209
# 2026-07-17 16:41:44,234 	Gloss Reference :	MORGEN MEISTENS SONNE
# 2026-07-17 16:41:44,234 	Gloss Hypothesis:	MORGEN MEISTENS SONNE
# 2026-07-17 16:41:44,235 	Gloss Alignment :
# 2026-07-17 16:41:44,235 ========================================================================================================================
# 2026-07-17 16:41:44,235 Logging Sequence: 07January_2010_Thursday_tagesschau-2301
# 2026-07-17 16:41:44,236 	Gloss Reference :	***** HEUTE  NACHT TEMPERATUR MINUS DREI MINUS SIEBZEHN WENN KLAR TIEF
# 2026-07-17 16:41:44,237 	Gloss Hypothesis:	FLUSS KOMMEN DREI  GRAD       MINUS DREI MINUS SIEBZEHN IX   KLAR INKOMMEND
# 2026-07-17 16:41:44,237 	Gloss Alignment :	I     S      S     S                                    S         S
# 2026-07-17 16:41:44,237 ========================================================================================================================
# 2026-07-17 16:41:44,238 Logging Sequence: 23August_2010_Monday_heute-5319
# 2026-07-17 16:41:44,238 	Gloss Reference :	FRISCH MORGEN ANGENEHM DEUTSCH LAND
# 2026-07-17 16:41:44,239 	Gloss Hypothesis:	WIND   MORGEN SCHWACH  DEUTSCH LAND
# 2026-07-17 16:41:44,239 	Gloss Alignment :	S             S
# 2026-07-17 16:41:44,240 ========================================================================================================================
# 2026-07-17 16:41:44,240 Logging Sequence: 10August_2011_Wednesday_tagesschau-6304
# 2026-07-17 16:41:44,240 	Gloss Reference :	SUED   MEHR FREUNDLICH IX NORD NICHT ORT    AUCH SCHAUER GEWITTER KURZ
# 2026-07-17 16:41:44,241 	Gloss Hypothesis:	REGION SUED FREUNDLICH ** NORD ***** REGION AUCH SCHAUER GEWITTER REGEN
# 2026-07-17 16:41:44,242 	Gloss Alignment :	S      S               D       D     S                            S
# 2026-07-17 16:41:44,242 ========================================================================================================================
# 2026-07-17 16:41:44,242 Logging Sequence: 28May_2010_Friday_tagesschau-7496
# 2026-07-17 16:41:44,243 	Gloss Reference :	HOCH KOMMEN OST KOMMEN ESBEDEUTET MORGEN FREUNDLICH WETTER
# 2026-07-17 16:41:44,243 	Gloss Hypothesis:	HOCH KOMMEN OST REGION DANN       MORGEN FREUNDLICH WETTER
# 2026-07-17 16:41:44,244 	Gloss Alignment :	                S      S
# 2026-07-17 16:41:44,244 ========================================================================================================================
# 2026-07-17 16:41:45,722 Epoch  10: Total Training Recognition Loss 248.54  Total Training Translation Loss -1.00
# 2026-07-17 16:41:45,806 Periodic checkpoint saved at epoch 10, step 15420 -> ../../runs/forward_warm_133_006/final/resume.ckpt
# 2026-07-17 16:41:45,807 EPOCH 11
# 2026-07-17 16:41:51,885 [Epoch: 011 Step: 00015500] Batch Recognition Loss:   1.118357 => Gls Tokens per Sec:     3281 || Lr: 0.000065
# 2026-07-17 16:42:05,141 Validation result at epoch  11, step    15500: duration: 13.2545s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 37.45754	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.45	(DEL: 14.99,	INS: 2.72,	SUB: 22.73)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:42:05,142 Logging Recognition and Translation Outputs
# 2026-07-17 16:42:05,142 ========================================================================================================================
# 2026-07-17 16:42:05,143 Logging Sequence: 30January_2013_Wednesday_tagesschau-475
# 2026-07-17 16:42:05,143 	Gloss Reference :	FREITAG DANN   KOMMEN REGEN IX             UEBERWIEGEND WIND
# 2026-07-17 16:42:05,144 	Gloss Hypothesis:	FREITAG WIEDER KOMMEN REGEN HAUPTSAECHLICH MEISTENS     WINTER
# 2026-07-17 16:42:05,144 	Gloss Alignment :	        S                   S              S            S
# 2026-07-17 16:42:05,145 ========================================================================================================================
# 2026-07-17 16:42:05,145 Logging Sequence: 21October_2009_Wednesday_tagesschau-735
# 2026-07-17 16:42:05,145 	Gloss Reference :	FRANKREICH KOMMEN WOLKE OST NIEDERSACHSEN BAYERN **** SUEDWEST REGEN
# 2026-07-17 16:42:05,146 	Gloss Hypothesis:	FRANKREICH KOMMEN WOLKE OST KOENNEN       BAYERN WEST SUEDWEST REGEN
# 2026-07-17 16:42:05,146 	Gloss Alignment :	                            S                    I
# 2026-07-17 16:42:05,146 ========================================================================================================================
# 2026-07-17 16:42:05,147 Logging Sequence: 04December_2009_Friday_tagesschau-841
# 2026-07-17 16:42:05,147 	Gloss Reference :	MANCHMAL SCHWACH MAESSIG IX WIND IX       WEST STARK WIND
# 2026-07-17 16:42:05,147 	Gloss Hypothesis:	BERG     SCHWACH MAESSIG IX **** NORDWEST NORD STARK WIND
# 2026-07-17 16:42:05,148 	Gloss Alignment :	S                           D    S        S
# 2026-07-17 16:42:05,148 ========================================================================================================================
# 2026-07-17 16:42:05,149 Logging Sequence: 20September_2010_Monday_heute-2934
# 2026-07-17 16:42:05,149 	Gloss Reference :	DABEI NORD MEHR MILD
# 2026-07-17 16:42:05,149 	Gloss Hypothesis:	DABEI NORD **** MILD
# 2026-07-17 16:42:05,150 	Gloss Alignment :	           D
# 2026-07-17 16:42:05,150 ========================================================================================================================
# 2026-07-17 16:42:05,150 Logging Sequence: 22November_2009_Sunday_tagesschau-5490
# 2026-07-17 16:42:05,151 	Gloss Reference :	NACHT      TEMPERATUR VIER BIS    NEUN
# 2026-07-17 16:42:05,151 	Gloss Hypothesis:	DONNERSTAG TEMPERATUR **** ZWOELF WOLKE
# 2026-07-17 16:42:05,152 	Gloss Alignment :	S                     D    S      S
# 2026-07-17 16:42:05,152 ========================================================================================================================
# 2026-07-17 16:42:05,152 Logging Sequence: 04January_2010_Monday_heute-7401
# 2026-07-17 16:42:05,153 	Gloss Reference :	REGION ANDERS MILD HINREICHEND HEUTE NACHT HINREICHEND SCHNEE
# 2026-07-17 16:42:05,153 	Gloss Hypothesis:	REGION EINS   MILD *********** HEUTE ***** *********** WOLKE
# 2026-07-17 16:42:05,153 	Gloss Alignment :	       S           D                 D     D           S
# 2026-07-17 16:42:05,154 ========================================================================================================================
# 2026-07-17 16:42:12,964 [Epoch: 011 Step: 00015600] Batch Recognition Loss:   1.167743 => Gls Tokens per Sec:     3182 || Lr: 0.000065
# 2026-07-17 16:42:26,317 Validation result at epoch  11, step    15600: duration: 13.3519s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 37.68292	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.21	(DEL: 14.49,	INS: 2.72,	SUB: 23.00)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:42:26,317 Logging Recognition and Translation Outputs
# 2026-07-17 16:42:26,318 ========================================================================================================================
# 2026-07-17 16:42:26,318 Logging Sequence: 12February_2010_Friday_tagesschau-125
# 2026-07-17 16:42:26,319 	Gloss Reference :	MORGEN MAL SONNE SPEZIELL ALPEN
# 2026-07-17 16:42:26,319 	Gloss Hypothesis:	MORGEN MAL SONNE SPEZIELL ALPEN
# 2026-07-17 16:42:26,320 	Gloss Alignment :
# 2026-07-17 16:42:26,320 ========================================================================================================================
# 2026-07-17 16:42:26,320 Logging Sequence: 24April_2010_Saturday_tagesschau-3963
# 2026-07-17 16:42:26,321 	Gloss Reference :	MORGEN AUCH HOCH LUFT VIEL SONNE
# 2026-07-17 16:42:26,321 	Gloss Hypothesis:	MORGEN AUCH **** LUFT VIEL SONNE
# 2026-07-17 16:42:26,322 	Gloss Alignment :	            D
# 2026-07-17 16:42:26,322 ========================================================================================================================
# 2026-07-17 16:42:26,322 Logging Sequence: 18November_2009_Wednesday_tagesschau-5587
# 2026-07-17 16:42:26,323 	Gloss Reference :	OST NACHT GEFAHR WIND
# 2026-07-17 16:42:26,323 	Gloss Hypothesis:	OST TAG   GEFAHR WIND
# 2026-07-17 16:42:26,324 	Gloss Alignment :	    S
# 2026-07-17 16:42:26,324 ========================================================================================================================
# 2026-07-17 16:42:26,324 Logging Sequence: 12December_2010_Sunday_tagesschau-5605
# 2026-07-17 16:42:26,325 	Gloss Reference :	TAG VOGEL LAND  MINUS ACHT NORD MINUS DREI GRAD
# 2026-07-17 16:42:26,325 	Gloss Hypothesis:	TAG NUR   WOLKE MINUS **** **** DREI  ZWEI GRAD
# 2026-07-17 16:42:26,326 	Gloss Alignment :	    S     S           D    D    S     S
# 2026-07-17 16:42:26,326 ========================================================================================================================
# 2026-07-17 16:42:26,326 Logging Sequence: 10January_2011_Monday_tagesschau-6409
# 2026-07-17 16:42:26,326 	Gloss Reference :	HEUTENACHT IX    EINS GRAD MINUS SIEBEN REGION
# 2026-07-17 16:42:26,327 	Gloss Hypothesis:	HEUTE      NACHT EINS GRAD MINUS SECHS  REGION
# 2026-07-17 16:42:26,327 	Gloss Alignment :	S          S                     S
# 2026-07-17 16:42:26,328 ========================================================================================================================
# 2026-07-17 16:42:26,328 Logging Sequence: 04July_2011_Monday_heute-6440
# 2026-07-17 16:42:26,329 	Gloss Reference :	IHR WUENSCHEN WISSEN      SOMMER WEITER           WIE   LAUFEN WIEAUSSEHEN DAMEN       UND HERREN possEUCH
# 2026-07-17 16:42:26,329 	Gloss Hypothesis:	*** WUENSCHEN WIEAUSSEHEN JETZT  ZEIGENBILDSCHIRM SCHON WEITER WETTER      WIEAUSSEHEN TAG TEIL   REGION
# 2026-07-17 16:42:26,329 	Gloss Alignment :	D             S           S      S                S     S      S           S           S   S      S
# 2026-07-17 16:42:26,330 ========================================================================================================================
# 2026-07-17 16:42:29,497 Epoch  11: Total Training Recognition Loss 246.47  Total Training Translation Loss -1.00
# 2026-07-17 16:42:29,498 Early stopping: no improvement in eval_metric for 10 epochs (best at epoch 1).
# 2026-07-17 16:42:29,498 Best validation result at step    13400:  39.83 eval_metric.
# 2026-07-17 16:42:46,123 ------------------------------------------------------------
# 2026-07-17 16:42:46,124 [DEV] partition [RECOGNITION] experiment [BW]: 1
# ================================
# COPE:  False
# ================================
# 2026-07-17 16:42:59,716 finished in 13.5916s
# 2026-07-17 16:42:59,716 ************************************************************
# 2026-07-17 16:42:59,717 [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 1
# 	WER 39.83	(DEL: 14.33,	INS: 2.85,	SUB: 22.65)
# 2026-07-17 16:42:59,717 ************************************************************
# 2026-07-17 16:42:59,717 ------------------------------------------------------------
# 2026-07-17 16:42:59,718 [DEV] partition [RECOGNITION] experiment [BW]: 2
# 2026-07-17 16:43:22,980 finished in 23.2626s
# 2026-07-17 16:43:22,981 ************************************************************
# 2026-07-17 16:43:22,981 [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 2
# 	WER 39.65	(DEL: 14.01,	INS: 2.93,	SUB: 22.71)
# 2026-07-17 16:43:22,982 ************************************************************
# 2026-07-17 16:43:22,982 ------------------------------------------------------------
# 2026-07-17 16:43:22,982 [DEV] partition [RECOGNITION] experiment [BW]: 3
# 2026-07-17 16:43:56,287 finished in 33.3047s
# 2026-07-17 16:43:56,288 ************************************************************
# 2026-07-17 16:43:56,288 [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 3
# 	WER 39.62	(DEL: 13.98,	INS: 2.96,	SUB: 22.68)
# 2026-07-17 16:43:56,289 ************************************************************
# 2026-07-17 16:43:56,289 ------------------------------------------------------------
# 2026-07-17 16:43:56,290 [DEV] partition [RECOGNITION] experiment [BW]: 4
# 2026-07-17 16:44:39,566 finished in 43.2768s
# 2026-07-17 16:44:39,567 ------------------------------------------------------------
# 2026-07-17 16:44:39,567 [DEV] partition [RECOGNITION] experiment [BW]: 5
# 2026-07-17 16:45:32,954 finished in 53.3865s
# 2026-07-17 16:45:32,955 ************************************************************
# 2026-07-17 16:45:32,955 [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 5
# 	WER 39.59	(DEL: 13.93,	INS: 2.96,	SUB: 22.71)
# 2026-07-17 16:45:32,955 ************************************************************
# 2026-07-17 16:45:32,956 ------------------------------------------------------------
# 2026-07-17 16:45:32,956 [DEV] partition [RECOGNITION] experiment [BW]: 6
# 2026-07-17 16:46:36,516 finished in 63.5603s
# 2026-07-17 16:46:36,517 ------------------------------------------------------------
# 2026-07-17 16:46:36,518 [DEV] partition [RECOGNITION] experiment [BW]: 7
# 2026-07-17 16:47:50,176 finished in 73.6587s
# 2026-07-17 16:47:50,177 ************************************************************
# 2026-07-17 16:47:50,178 [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 7
# 	WER 39.51	(DEL: 13.95,	INS: 2.96,	SUB: 22.60)
# 2026-07-17 16:47:50,178 ************************************************************
# 2026-07-17 16:47:50,178 ------------------------------------------------------------
# 2026-07-17 16:47:50,179 [DEV] partition [RECOGNITION] experiment [BW]: 8
# 2026-07-17 16:49:13,758 finished in 83.5788s
# 2026-07-17 16:49:13,758 ------------------------------------------------------------
# 2026-07-17 16:49:13,759 [DEV] partition [RECOGNITION] experiment [BW]: 9
# 2026-07-17 16:50:47,296 finished in 93.5370s
# 2026-07-17 16:50:47,296 ------------------------------------------------------------
# 2026-07-17 16:50:47,297 [DEV] partition [RECOGNITION] experiment [BW]: 10
# 2026-07-17 16:52:30,955 finished in 103.6580s
# 2026-07-17 16:52:30,956 ************************************************************
# 2026-07-17 16:52:30,956 [DEV] partition [Recognition & Translation] results:
# 	Best CTC Decode Beam Size: 7
# 	Best Translation Beam Size: -1 and Alpha: -1
# 	WER 39.51	(DEL: 13.95,	INS: 2.96,	SUB: 22.60)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:52:30,956 ************************************************************
# 2026-07-17 16:53:54,888 [TEST] partition [Recognition & Translation] results:
# 	Best CTC Decode Beam Size: 7
# 	Best Translation Beam Size: -1 and Alpha: -1
# 	WER 40.83	(DEL: 13.44,	INS: 3.96,	SUB: 23.43)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 16:53:54,889 ************************************************************

# %%
# Curves: train loss and validation loss (left), dev WER (right).
import re
import matplotlib.pyplot as plt
from main.helpers import parse_validations

MDIR = os.path.join(RUN_DIR, 'final')
val = parse_validations(MDIR)   # steps, recognition_loss (dev), wer, lr

# Train loss is logged per step in train.log, not in validations.txt.
tr_steps, tr_loss = [], []
logp = os.path.join(MDIR, 'train.log')
if os.path.exists(logp):
    for line in open(logp, encoding='utf-8', errors='ignore'):
        ms = re.search(r'Step:\s*(\d+)', line)
        ml = re.search(r'Batch Recognition Loss:\s*([\d.]+)', line)
        if ms and ml:
            tr_steps.append(int(ms.group(1)))
            tr_loss.append(float(ml.group(1)))

if not val['steps'] and not tr_steps:
    print('no logs yet in', MDIR, '(train first, DO_TRAIN = True)')
else:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4.5))

    if tr_steps:
        ax1.plot(tr_steps, tr_loss, lw=0.8, alpha=0.5, color='tab:blue', label='train loss')
    if val['steps']:
        ax1.plot(val['steps'], val['recognition_loss'], marker='o', ms=3,
                 color='tab:red', label='val loss')
    ax1.set_xlabel('step'); ax1.set_ylabel('CTC loss'); ax1.set_title('Loss')
    ax1.legend(); ax1.grid(alpha=0.3)

    if val['steps']:
        ax2.plot(val['steps'], val['wer'], marker='o', ms=3, color='crimson', label='dev WER')
        ax2.axhline(39.54, ls='--', c='gray', label='baseline (greedy) 39.54')
        good = [(s, w) for s, w in zip(val['steps'], val['wer']) if w == w]
        if good:
            bs, bw = min(good, key=lambda t: t[1])
            ax2.scatter([bs], [bw], color='black', zorder=5, label='best %.2f' % bw)
    ax2.set_xlabel('step'); ax2.set_ylabel('dev WER (%)'); ax2.set_title('Dev WER')
    ax2.legend(); ax2.grid(alpha=0.3)

    fig.tight_layout()
    fig.savefig(os.path.join(MDIR, 'training_curves.png'), dpi=120)
    plt.show()

    if val['steps']:
        good = [(s, w) for s, w in zip(val['steps'], val['wer']) if w == w]
        if good:
            bs, bw = min(good, key=lambda t: t[1])
            print('best dev WER : %.2f at step %d' % (bw, bs))
        vl = [x for x in val['recognition_loss'] if x == x]
        if vl:
            print('last val loss: %.3f' % vl[-1])
    if tr_loss:
        print('last train loss: %.3f' % tr_loss[-1])
# Out:
# best dev WER : 39.83 at step 13400
# last val loss: 37.683
# last train loss: 1.168

# %%
# Evaluate the best-on-dev checkpoint and lay the numbers next to the baseline.
best_ckpt = os.path.join(RUN_DIR, 'final', 'best.ckpt')
if not os.path.exists(best_ckpt):
    print('no best.ckpt yet -- train first (DO_TRAIN = True).')
else:
    mt.test(ACTIVE_CFG, ckpt=best_ckpt, output_path=os.path.join(RUN_DIR, 'final', 'test_output'))
    print()
    print('Baseline, from scratch, CTC only (sign.yaml):')
    print('   dev  39.54 greedy / 39.35 beam-4      test  41.53')
    print('This run, from scratch, CTC + FD-CMKD:')
    print('   see the [DEV] and [TEST] WER printed above')
    print()
    print('Reading the result:')
    print(' - below baseline beyond the margin: warm-start was hiding a real transfer.')
    print(' - within the margin: the last alternative explanation is ruled out.')
    print(' - above baseline: a weak teacher shaping the representation transfers its confusion.')
# Out:
# 2026-07-17 16:54:11,531 - ------------------------------------------------------------
# 2026-07-17 16:54:11,531 - [DEV] partition [RECOGNITION] experiment [BW]: 1
# ================================
# COPE:  False
# ================================
# 2026-07-17 16:54:25,022 - finished in 13.4910s
# 2026-07-17 16:54:25,023 - ************************************************************
# 2026-07-17 16:54:25,023 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 1
# 	WER 39.83	(DEL: 14.33,	INS: 2.85,	SUB: 22.65)
# 2026-07-17 16:54:25,024 - ************************************************************
# 2026-07-17 16:54:25,024 - ------------------------------------------------------------
# 2026-07-17 16:54:25,024 - [DEV] partition [RECOGNITION] experiment [BW]: 2
# 2026-07-17 16:54:48,143 - finished in 23.1188s
# 2026-07-17 16:54:48,143 - ************************************************************
# 2026-07-17 16:54:48,144 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 2
# 	WER 39.65	(DEL: 14.01,	INS: 2.93,	SUB: 22.71)
# 2026-07-17 16:54:48,144 - ************************************************************
# 2026-07-17 16:54:48,145 - ------------------------------------------------------------
# 2026-07-17 16:54:48,145 - [DEV] partition [RECOGNITION] experiment [BW]: 3
# 2026-07-17 16:55:21,264 - finished in 33.1190s
# 2026-07-17 16:55:21,265 - ************************************************************
# 2026-07-17 16:55:21,265 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 3
# 	WER 39.62	(DEL: 13.98,	INS: 2.96,	SUB: 22.68)
# 2026-07-17 16:55:21,265 - ************************************************************
# 2026-07-17 16:55:21,266 - ------------------------------------------------------------
# 2026-07-17 16:55:21,266 - [DEV] partition [RECOGNITION] experiment [BW]: 4
# 2026-07-17 16:56:04,393 - finished in 43.1271s
# 2026-07-17 16:56:04,394 - ------------------------------------------------------------
# 2026-07-17 16:56:04,394 - [DEV] partition [RECOGNITION] experiment [BW]: 5
# 2026-07-17 16:56:57,549 - finished in 53.1556s
# 2026-07-17 16:56:57,550 - ************************************************************
# 2026-07-17 16:56:57,550 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 5
# 	WER 39.59	(DEL: 13.93,	INS: 2.96,	SUB: 22.71)
# 2026-07-17 16:56:57,551 - ************************************************************
# 2026-07-17 16:56:57,551 - ------------------------------------------------------------
# 2026-07-17 16:56:57,551 - [DEV] partition [RECOGNITION] experiment [BW]: 6
# 2026-07-17 16:58:00,860 - finished in 63.3089s
# 2026-07-17 16:58:00,861 - ------------------------------------------------------------
# 2026-07-17 16:58:00,861 - [DEV] partition [RECOGNITION] experiment [BW]: 7
# 2026-07-17 16:59:14,229 - finished in 73.3684s
# 2026-07-17 16:59:14,230 - ************************************************************
# 2026-07-17 16:59:14,230 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 7
# 	WER 39.51	(DEL: 13.95,	INS: 2.96,	SUB: 22.60)
# 2026-07-17 16:59:14,231 - ************************************************************
# 2026-07-17 16:59:14,231 - ------------------------------------------------------------
# 2026-07-17 16:59:14,232 - [DEV] partition [RECOGNITION] experiment [BW]: 8
# 2026-07-17 17:00:37,650 - finished in 83.4189s
# 2026-07-17 17:00:37,651 - ------------------------------------------------------------
# 2026-07-17 17:00:37,651 - [DEV] partition [RECOGNITION] experiment [BW]: 9
# 2026-07-17 17:02:10,554 - finished in 92.9029s
# 2026-07-17 17:02:10,555 - ------------------------------------------------------------
# 2026-07-17 17:02:10,555 - [DEV] partition [RECOGNITION] experiment [BW]: 10
# 2026-07-17 17:03:53,499 - finished in 102.9443s
# 2026-07-17 17:03:53,500 - ************************************************************
# 2026-07-17 17:03:53,500 - [DEV] partition [Recognition & Translation] results:
# 	Best CTC Decode Beam Size: 7
# 	Best Translation Beam Size: -1 and Alpha: -1
# 	WER 39.51	(DEL: 13.95,	INS: 2.96,	SUB: 22.60)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 17:03:53,501 - ************************************************************
# 2026-07-17 17:05:16,823 - [TEST] partition [Recognition & Translation] results:
# 	Best CTC Decode Beam Size: 7
# 	Best Translation Beam Size: -1 and Alpha: -1
# 	WER 40.83	(DEL: 13.44,	INS: 3.96,	SUB: 23.43)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-17 17:05:16,824 - ************************************************************
# Baseline, from scratch, CTC only (sign.yaml):
#    dev  39.54 greedy / 39.35 beam-4      test  41.53
# This run, from scratch, CTC + FD-CMKD:
#    see the [DEV] and [TEST] WER printed above
#
# Reading the result:
#  - below baseline beyond the margin: warm-start was hiding a real transfer.
#  - within the margin: the last alternative explanation is ruled out.
#  - above baseline: a weak teacher shaping the representation transfers its confusion.
