# %% [markdown]
# # FD-CMKD warm-start
#
# This is the regime the thesis reports: the student is **warm-started** from the
# converged CTC-only baseline and fine-tuned with the FD-CMKD transfer loss at a
# small, re-tuned learning rate. It answers *does the teacher improve an
# already-trained student?*
#
# It is the twin of `run_from_scratch_distill.ipynb`. The two notebooks are identical
# except for the config they load: this one uses `warm_start_fd_cmkd.yaml`, which
# carries `load_model` and the small learning rate; the other trains from random
# initialization at the baseline learning rate with a distillation-weight warmup.
# Running both and comparing each against the CTC-only baseline (39.54 dev / 41.53
# test) separates the effect of the teacher from the effect of the training regime.
#
# **On the comparison.** Warm-start confounds the transfer with extra fine-tuning:
# the distilled student sees more gradient steps than the baseline and a fresh lr
# search. Read against the starting checkpoint it is not evidence; the sound
# comparison is the matched control of `run_optuna.ipynb`. This notebook exists to
# reproduce the reported warm-start numbers and to pair cleanly with the from-scratch
# run.

# %%
# Run from code/distillation/ no matter where the kernel was launched.
import os
if not os.path.exists('fd_cmkd.py'):
    _cwd = os.getcwd()
    for _k in range(0, 6):
        _base = os.path.abspath(os.path.join(_cwd, *(['..'] * _k)))
        _cand = os.path.join(_base, 'code', 'distillation')
        if os.path.exists(os.path.join(_cand, 'fd_cmkd.py')):
            os.chdir(_cand); break
        if os.path.exists(os.path.join(_base, 'fd_cmkd.py')):
            os.chdir(_base); break
print('working dir:', os.getcwd())

# Where this run writes -- same convention as the other notebooks.
# Output goes to runs/<RUN_NAME>/; dataset/checkpoints/ is never touched.
import os

RUN_NAME  = 'forward_warm_control'
OVERWRITE = False        # False: version to _002, _003, ... instead of deleting
DO_TRAIN  = False        # True: train from scratch (up to 1000 epochs, early-stopped)

RUN_DIR = os.path.join('../../runs', RUN_NAME)
if os.path.exists(RUN_DIR) and not OVERWRITE:
    _n = 2
    while os.path.exists('%s_%03d' % (RUN_DIR, _n)):
        _n += 1
    RUN_DIR = '%s_%03d' % (RUN_DIR, _n)
print('this run writes to:', os.path.normpath(os.path.abspath(RUN_DIR)))

# This notebook evaluates only its own run.
EVAL_CKPT = 'mine'
# Out:
# working dir: /home/ebufi/Sign-Language-Recognition/code/distillation
# this run writes to: /home/ebufi/Sign-Language-Recognition/runs/forward_warm_control_002

# %%
import sys, yaml

SIGNFORMER_DIR = os.path.abspath('../signformer')   # for `import main.*`
NB_DIR = os.path.abspath('.')                        # for `import fd_cmkd*`
for _p in (SIGNFORMER_DIR, NB_DIR):
    if _p not in sys.path:
        sys.path.insert(0, _p)

import main.training as mt
from fd_cmkd_trainer import train_fd_cmkd
from fd_cmkd import load_teacher_feats
print('imports OK')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783953903.930659 2142948 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# imports OK

# %%
# Sanity checks: data and teacher features present, config genuinely from-scratch.
BASE_CFG = 'warm_start_fd_cmkd.yaml'
assert os.path.exists(BASE_CFG), 'missing config: ' + BASE_CFG

cfg = yaml.safe_load(open(BASE_CFG))
dc = cfg['training']['distillation']

i3d = os.path.join(cfg['data']['data_path'], cfg['data']['train'])
assert os.path.exists(i3d), 'missing I3D features: ' + i3d

tfp = os.path.join(dc['teacher_feats_dir'], 'train.pkl')
assert os.path.exists(tfp), 'missing teacher features: ' + tfp
_t = load_teacher_feats(tfp)

assert 'load_model' in cfg['training'], 'a warm-start run must load the baseline checkpoint'
print('i3d train features : OK')
print('teacher features   : %d videos, dim %d' % (len(_t), next(iter(_t.values())).shape[1]))
print('warm-start         : loads', cfg['training']['load_model'])
print('distill warmup     : %d steps (0 = off for warm-start)' % dc['distill_warmup_steps'])
# Out:
# i3d train features : OK
# teacher features   : 7096 videos, dim 512
# warm-start         : loads ../../dataset/checkpoints/sign_sample/best.ckpt
# distill warmup     : 0 steps (0 = off for warm-start)

# %%
# === MATCHED CONTROL for Module 2 (future works) — teacher disabled ===
cfg['training']['distillation']['enabled'] = False
DO_TRAIN = True
print('CONTROL ARM (Module 2): teacher OFF -> plain warm-start fine-tuning')
# Out:
# CONTROL ARM (Module 2): teacher OFF -> plain warm-start fine-tuning

# %%
# Point the config at RUN_DIR, honour OVERWRITE, write the resolved config there.
# The committed warm_start_fd_cmkd.yaml is never modified.
# RUN_DIR is a container. The trainer writes into RUN_DIR/final, which it must
# be free to create fresh: make_model_dir refuses a directory that already
# exists. Writing the config into RUN_DIR (not into MODEL_DIR) keeps them apart.
MODEL_DIR = os.path.join(RUN_DIR, 'final')
cfg['training']['model_dir'] = MODEL_DIR
cfg['training']['overwrite'] = OVERWRITE

os.makedirs(RUN_DIR, exist_ok=True)
ACTIVE_CFG = os.path.join(RUN_DIR, 'warm_start_fd_cmkd.yaml')
with open(ACTIVE_CFG, 'w') as f:
    yaml.safe_dump(cfg, f, sort_keys=False)

tr = cfg['training']
print('active config ->', ACTIVE_CFG)
print('lr=%.3e  wd=%.3e  batch=%d  patience=%d' % (tr['learning_rate'], tr['weight_decay'], tr['batch_size'], tr['early_stopping_patience']))
print('lambda_feat=%.3f  lambda_align=%.3f  w_high=%.3f  warmup=%d' % (dc['lambda_feat'], dc['lambda_align'], dc['high_w'], dc['distill_warmup_steps']))
# Out:
# active config -> ../../runs/forward_warm_control_002/warm_start_fd_cmkd.yaml
# lr=8.182e-05  wd=3.000e-03  batch=32  patience=10
# lambda_feat=0.161  lambda_align=0.150  w_high=0.292  warmup=0

# %% [markdown]
# ## Optional: matched learning-rate search
#
# The baseline was selected over a small Optuna search. For the comparison to be fair,
# the from-scratch distilled arm deserves a search of the **same budget** over the
# **same learning-rate range**. Turn it on to run it; each trial writes to a temporary
# directory under `RUN_DIR`, and the best learning rate is kept.
#
# Leave it off (`USE_OPTUNA = False`) to train a single run at the baseline learning
# rate -- a quick check that the pipeline works, but not, on its own, evidence.

# %%
import copy, shutil, gc

USE_OPTUNA    = False   # True re-runs the matched search (hours)
OPTUNA_TRIALS = 6       # match the baseline budget
LR_RANGE      = (1.5e-4, 6e-4)   # a neighbourhood of the baseline 3.12e-4

if USE_OPTUNA and DO_TRAIN:
    import torch
    try:
        import optuna
    except ImportError:
        import subprocess
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'optuna'])
        import optuna
    optuna.logging.set_verbosity(optuna.logging.WARNING)

    _log = []
    def _objective(trial):
        lr = trial.suggest_float('learning_rate', LR_RANGE[0], LR_RANGE[1], log=True)
        ct = copy.deepcopy(cfg)
        ct['training']['learning_rate'] = float(lr)
        td = os.path.join(RUN_DIR, 'optuna', 'trial_%02d' % trial.number)
        ct['training']['model_dir'] = td
        ct['training']['overwrite'] = True
        # config beside the trial dir, not inside: make_model_dir wipes the
        # dir (overwrite=True) and would delete a config written into it.
        os.makedirs(os.path.dirname(td), exist_ok=True)
        cf = td + '.yaml'
        with open(cf, 'w') as f:
            yaml.safe_dump(ct, f, sort_keys=False)
        train_fd_cmkd(cf)
        wers = []
        vf = os.path.join(ct['training']['model_dir'], 'validations.txt')
        if os.path.exists(vf):
            for line in open(vf):
                toks = line.replace(':', ' ').split()
                if 'WER' in toks:
                    try:
                        wers.append(float(toks[toks.index('WER') + 1]))
                    except (ValueError, IndexError):
                        pass
        best = min(wers) if wers else 100.0
        _log.append((trial.number, lr, best))
        print('  trial %d: lr=%.3e -> dev WER %.2f' % (trial.number, lr, best))
        shutil.rmtree(td, ignore_errors=True)
        if os.path.exists(cf):
            os.remove(cf)
        gc.collect(); torch.cuda.empty_cache()
        return best

    study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(_objective, n_trials=OPTUNA_TRIALS)
    print('best lr:', study.best_params, '-> dev WER', round(study.best_value, 2))
    cfg['training']['learning_rate'] = float(study.best_params['learning_rate'])
    with open(ACTIVE_CFG, 'w') as f:
        yaml.safe_dump(cfg, f, sort_keys=False)
    print('ACTIVE_CFG updated with the searched learning rate.')
else:
    print('Optuna search disabled (or DO_TRAIN=False) -- using the config lr.')
# Out:
# Optuna search disabled (or DO_TRAIN=False) -- using the config lr.

# %%
import torch
torch.backends.cudnn.enabled = False

# Train from scratch. This is the long cell.
if DO_TRAIN:
    train_fd_cmkd(ACTIVE_CFG)
else:
    print('DO_TRAIN = False -> skipping training. Set it True to run from scratch.')
# Out:
# 2026-07-13 16:45:23,859 Hello! This is SL-CAT.
# 2026-07-13 16:45:23,861 Total params: 3,757,577
# 2026-07-13 16:45:23,862 Trainable parameters: ['encoder.layer_norm.bias', 'encoder.layer_norm.weight', 'encoder.layers.0.FF2.module.layer_norm.bias', 'encoder.layers.0.FF2.module.layer_norm.weight', 'encoder.layers.0.FF2.module.pwff_layer.0.bias', 'encoder.layers.0.FF2.module.pwff_layer.0.weight', 'encoder.layers.0.FF2.module.pwff_layer.3.bias', 'encoder.layers.0.FF2.module.pwff_layer.3.weight', 'encoder.layers.0.att.module.attention.attn_net.bias', 'encoder.layers.0.att.module.attention.attn_net.weight', 'encoder.layers.0.att.module.attention.k_proj.bias', 'encoder.layers.0.att.module.attention.k_proj.weight', 'encoder.layers.0.att.module.attention.offset_net.0.bias', 'encoder.layers.0.att.module.attention.offset_net.0.weight', 'encoder.layers.0.att.module.attention.offset_net.2.bias', 'encoder.layers.0.att.module.attention.offset_net.2.weight', 'encoder.layers.0.att.module.attention.out_proj.bias', 'encoder.layers.0.att.module.attention.out_proj.weight', 'encoder.layers.0.att.module.attention.q_proj.bias', 'encoder.layers.0.att.module.attention.q_proj.weight', 'encoder.layers.0.att.module.attention.v_proj.bias', 'encoder.layers.0.att.module.attention.v_proj.weight', 'encoder.layers.0.att.module.layer_norm.bias', 'encoder.layers.0.att.module.layer_norm.weight', 'encoder.layers.0.convMod.module.dep1.conv.weight', 'encoder.layers.0.convMod.module.layerNorm.bias', 'encoder.layers.0.convMod.module.layerNorm.weight', 'encoder.layers.0.convMod.module.layerNorm2.bias', 'encoder.layers.0.convMod.module.layerNorm2.weight', 'encoder.layers.0.convMod.module.point1.conv.bias', 'encoder.layers.0.convMod.module.point1.conv.weight', 'encoder.layers.0.convMod.module.point2.conv.bias', 'encoder.layers.0.convMod.module.point2.conv.weight', 'encoder.layers.0.layerNORM.bias', 'encoder.layers.0.layerNORM.weight', 'encoder.layers.1.FF2.module.layer_norm.bias', 'encoder.layers.1.FF2.module.layer_norm.weight', 'encoder.layers.1.FF2.module.pwff_layer.0.bias', 'encoder.layers.1.FF2.module.pwff_layer.0.weight', 'encoder.layers.1.FF2.module.pwff_layer.3.bias', 'encoder.layers.1.FF2.module.pwff_layer.3.weight', 'encoder.layers.1.att.module.attention.attn_net.bias', 'encoder.layers.1.att.module.attention.attn_net.weight', 'encoder.layers.1.att.module.attention.k_proj.bias', 'encoder.layers.1.att.module.attention.k_proj.weight', 'encoder.layers.1.att.module.attention.offset_net.0.bias', 'encoder.layers.1.att.module.attention.offset_net.0.weight', 'encoder.layers.1.att.module.attention.offset_net.2.bias', 'encoder.layers.1.att.module.attention.offset_net.2.weight', 'encoder.layers.1.att.module.attention.out_proj.bias', 'encoder.layers.1.att.module.attention.out_proj.weight', 'encoder.layers.1.att.module.attention.q_proj.bias', 'encoder.layers.1.att.module.attention.q_proj.weight', 'encoder.layers.1.att.module.attention.v_proj.bias', 'encoder.layers.1.att.module.attention.v_proj.weight', 'encoder.layers.1.att.module.layer_norm.bias', 'encoder.layers.1.att.module.layer_norm.weight', 'encoder.layers.1.convMod.module.dep1.conv.weight', 'encoder.layers.1.convMod.module.layerNorm.bias', 'encoder.layers.1.convMod.module.layerNorm.weight', 'encoder.layers.1.convMod.module.layerNorm2.bias', 'encoder.layers.1.convMod.module.layerNorm2.weight', 'encoder.layers.1.convMod.module.point1.conv.bias', 'encoder.layers.1.convMod.module.point1.conv.weight', 'encoder.layers.1.convMod.module.point2.conv.bias', 'encoder.layers.1.convMod.module.point2.conv.weight', 'encoder.layers.1.layerNORM.bias', 'encoder.layers.1.layerNORM.weight', 'encoder.layers.2.FF2.module.layer_norm.bias', 'encoder.layers.2.FF2.module.layer_norm.weight', 'encoder.layers.2.FF2.module.pwff_layer.0.bias', 'encoder.layers.2.FF2.module.pwff_layer.0.weight', 'encoder.layers.2.FF2.module.pwff_layer.3.bias', 'encoder.layers.2.FF2.module.pwff_layer.3.weight', 'encoder.layers.2.att.module.attention.attn_net.bias', 'encoder.layers.2.att.module.attention.attn_net.weight', 'encoder.layers.2.att.module.attention.k_proj ...
# ================================
# COPE:  False
# ================================
# [builders] SophiaG unavailable, falling back to Adam
# /home/ebufi/venv/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 2026-07-13 16:45:24,553 Loading model from ../../dataset/checkpoints/sign_sample/best.ckpt
# 2026-07-13 16:45:24,609 Reset optimizer.
# 2026-07-13 16:45:24,610 Reset scheduler.
# 2026-07-13 16:45:24,610 Reset tracking of the best checkpoint.
# 2026-07-13 16:45:24,612 FD-CMKD disabled — plain finetuning.
# 2026-07-13 16:45:24,612 Data set sizes:
# 	train 7094,
# 	valid 519,
# 	test 642
# 2026-07-13 16:45:24,612 First training example:
# 	[GLS] JETZT WETTER MORGEN DONNERSTAG ZWOELF FEBRUAR
# 	[TXT] und nun die wettervorhersage für morgen donnerstag den zwölften august
# 2026-07-13 16:45:24,613 First 10 words (gls): (0) <si> (1) <unk> (2) <pad> (3) REGEN (4) REGION (5) IX (6) KOMMEN (7) MORGEN (8) NORD (9) SONNE
# 2026-07-13 16:45:24,613 First 10 words (txt): (0) <unk> (1) <pad> (2) <s> (3) </s> (4) und (5) im (6) es (7) der (8) am (9) in
# 2026-07-13 16:45:24,614 Number of unique glosses (types): 1087
# 2026-07-13 16:45:24,614 Number of unique words (types): 2888
# 2026-07-13 16:45:24,616 EPOCH 1
# 2026-07-13 16:45:30,564 [Epoch: 001 Step: 00013300] Batch Recognition Loss:   1.225983 => Gls Tokens per Sec:     4180 || Lr: 0.000082
# 2026-07-13 16:45:44,202 Hooray! New best validation result [eval_metric]!
# 2026-07-13 16:45:44,202 Saving new checkpoint.
# 2026-07-13 16:45:44,258 Validation result at epoch   1, step    13300: duration: 13.6938s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.09229	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.05	(DEL: 17.05,	INS: 1.92,	SUB: 21.08)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:45:44,259 Logging Recognition and Translation Outputs
# 2026-07-13 16:45:44,259 ========================================================================================================================
# 2026-07-13 16:45:44,260 Logging Sequence: 10March_2011_Thursday_heute-51
# 2026-07-13 16:45:44,260 	Gloss Reference :	SUEDWEST KOMMEN WARM MORGEN SCHON FRANKREICH REGION FUENFZEHN BIS ZWANZIG GRAD WOCHENENDE KOMMEN WARM
# 2026-07-13 16:45:44,261 	Gloss Hypothesis:	SUEDWEST ****** WARM ****** SCHON ********** LAND   VIERZEHN  BIS ZWANZIG GRAD WOCHENENDE KOMMEN WARM
# 2026-07-13 16:45:44,261 	Gloss Alignment :	         D           D            D          S      S
# 2026-07-13 16:45:44,261 ========================================================================================================================
# 2026-07-13 16:45:44,262 Logging Sequence: 28November_2011_Monday_heute-1587
# 2026-07-13 16:45:44,262 	Gloss Reference :	AUCH MORGEN WETTER SUPER negHABEN FUENF GRAD NORDOST MILD WO   SUEDWEST
# 2026-07-13 16:45:44,263 	Gloss Hypothesis:	**** MORGEN WETTER ***** negHABEN FUENF GRAD ******* **** NORD TEIL
# 2026-07-13 16:45:44,263 	Gloss Alignment :	D                  D                         D       D    S    S
# 2026-07-13 16:45:44,264 ========================================================================================================================
# 2026-07-13 16:45:44,264 Logging Sequence: 07April_2010_Wednesday_heute-1631
# 2026-07-13 16:45:44,264 	Gloss Reference :	FREUNDLICH BLEIBEN REGION SUED BISSCHEN SCHAUER
# 2026-07-13 16:45:44,265 	Gloss Hypothesis:	ABER       BLEIBEN ****** OST  BISSCHEN SCHAUER
# 2026-07-13 16:45:44,265 	Gloss Alignment :	S                  D      S
# 2026-07-13 16:45:44,266 ========================================================================================================================
# 2026-07-13 16:45:44,266 Logging Sequence: 01July_2011_Friday_tagesschau-2765
# 2026-07-13 16:45:44,266 	Gloss Reference :	HEUTE NACHT ***** DREIZEHN NORD   VIER    BERG
# 2026-07-13 16:45:44,267 	Gloss Hypothesis:	HEUTE NACHT FLUSS DREIZEHN REGION ZWANZIG ALPEN
# 2026-07-13 16:45:44,267 	Gloss Alignment :	            I              S      S       S
# 2026-07-13 16:45:44,267 ========================================================================================================================
# 2026-07-13 16:45:44,268 Logging Sequence: 19March_2011_Saturday_tagesschau-4690
# 2026-07-13 16:45:44,268 	Gloss Reference :	MORGEN FRUEH VERSCHWINDEN LANGSAM SCHNELL NORDOST BISSCHEN WOLKE BLEIBEN TROCKEN
# 2026-07-13 16:45:44,269 	Gloss Hypothesis:	MORGEN ***** VERSCHWINDEN LANGSAM ******* KALT    BISSCHEN ***** ******* OST
# 2026-07-13 16:45:44,269 	Gloss Alignment :	       D                          D       S                D     D       S
# 2026-07-13 16:45:44,269 ========================================================================================================================
# 2026-07-13 16:45:44,270 Logging Sequence: 24January_2010_Sunday_tagesschau-8710
# 2026-07-13 16:45:44,270 	Gloss Reference :	SUED SCHWACH WEHEN IX MAESSIG WEHEN
# 2026-07-13 16:45:44,271 	Gloss Hypothesis:	SUED SCHWACH WEHEN IX MAESSIG WEHEN
# 2026-07-13 16:45:44,271 	Gloss Alignment :
# 2026-07-13 16:45:44,271 ========================================================================================================================
# 2026-07-13 16:45:49,855 [Epoch: 001 Step: 00013400] Batch Recognition Loss:   1.656545 => Gls Tokens per Sec:     4449 || Lr: 0.000082
# 2026-07-13 16:46:03,541 Validation result at epoch   1, step    13400: duration: 13.6859s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.08665	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.34	(DEL: 16.54,	INS: 2.19,	SUB: 21.61)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:46:03,542 Logging Recognition and Translation Outputs
# 2026-07-13 16:46:03,542 ========================================================================================================================
# 2026-07-13 16:46:03,543 Logging Sequence: 24November_2011_Thursday_heute-222
# 2026-07-13 16:46:03,544 	Gloss Reference :	NORD NUR  WOLKE **** FROST SUED
# 2026-07-13 16:46:03,544 	Gloss Hypothesis:	NORD AUCH WOLKE KALT FROST SUED
# 2026-07-13 16:46:03,544 	Gloss Alignment :	     S          I
# 2026-07-13 16:46:03,545 ========================================================================================================================
# 2026-07-13 16:46:03,545 Logging Sequence: 14October_2009_Wednesday_tagesschau-529
# 2026-07-13 16:46:03,545 	Gloss Reference :	BESONDERS NORDWEST WIND STARK
# 2026-07-13 16:46:03,546 	Gloss Hypothesis:	BESONDERS NORDWEST WIND STARK
# 2026-07-13 16:46:03,546 	Gloss Alignment :
# 2026-07-13 16:46:03,546 ========================================================================================================================
# 2026-07-13 16:46:03,547 Logging Sequence: 17October_2009_Saturday_tagesschau-2127
# 2026-07-13 16:46:03,547 	Gloss Reference :	TIEF REGION SCHWACH MORGEN SOLL EINFLUSS OST REGION SUED
# 2026-07-13 16:46:03,548 	Gloss Hypothesis:	TIEF MEHR   SCHWACH MORGEN **** FLUSS    OST ****** SUED
# 2026-07-13 16:46:03,548 	Gloss Alignment :	     S                     D    S            D
# 2026-07-13 16:46:03,548 ========================================================================================================================
# 2026-07-13 16:46:03,549 Logging Sequence: 17October_2009_Saturday_tagesschau-2139
# 2026-07-13 16:46:03,549 	Gloss Reference :	NEBEL KUEHL
# 2026-07-13 16:46:03,549 	Gloss Hypothesis:	NEBEL ENORM
# 2026-07-13 16:46:03,550 	Gloss Alignment :	      S
# 2026-07-13 16:46:03,550 ========================================================================================================================
# 2026-07-13 16:46:03,550 Logging Sequence: 10August_2011_Wednesday_tagesschau-6303
# 2026-07-13 16:46:03,550 	Gloss Reference :	IMVERLAUF IMVERLAUF TEMPERATUR REGION
# 2026-07-13 16:46:03,551 	Gloss Hypothesis:	********* IMVERLAUF TEMPERATUR ******
# 2026-07-13 16:46:03,551 	Gloss Alignment :	D                              D
# 2026-07-13 16:46:03,552 ========================================================================================================================
# 2026-07-13 16:46:03,552 Logging Sequence: 09April_2010_Friday_tagesschau-7623
# 2026-07-13 16:46:03,552 	Gloss Reference :	JETZT WETTER MORGEN SAMSTAG ZEHNTE APRIL WIEAUSSEHEN ZEIGENBILDSCHIRM
# 2026-07-13 16:46:03,553 	Gloss Hypothesis:	JETZT WETTER MORGEN ******* MEHR   APRIL WIEAUSSEHEN ****************
# 2026-07-13 16:46:03,553 	Gloss Alignment :	                    D       S                        D
# 2026-07-13 16:46:03,553 ========================================================================================================================
# 2026-07-13 16:46:04,726 Epoch   1: Total Training Recognition Loss 292.95  Total Training Translation Loss -1.00
# 2026-07-13 16:46:04,726 EPOCH 2
# 2026-07-13 16:46:09,617 [Epoch: 002 Step: 00013500] Batch Recognition Loss:   1.627195 => Gls Tokens per Sec:     3969 || Lr: 0.000082
# 2026-07-13 16:46:23,202 Validation result at epoch   2, step    13500: duration: 13.5847s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.30860	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.93	(DEL: 17.00,	INS: 2.40,	SUB: 21.53)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:46:23,202 Logging Recognition and Translation Outputs
# 2026-07-13 16:46:23,203 ========================================================================================================================
# 2026-07-13 16:46:23,203 Logging Sequence: 15December_2010_Wednesday_tagesschau-40
# 2026-07-13 16:46:23,204 	Gloss Reference :	DANN STARK SCHNEE SCHNEIEN KOMMEN
# 2026-07-13 16:46:23,204 	Gloss Hypothesis:	DANN ***** SCHNEE SCHNEIEN KOMMEN
# 2026-07-13 16:46:23,205 	Gloss Alignment :	     D
# 2026-07-13 16:46:23,205 ========================================================================================================================
# 2026-07-13 16:46:23,205 Logging Sequence: 01December_2011_Thursday_heute-3061
# 2026-07-13 16:46:23,206 	Gloss Reference :	ABER  DAZWISCHEN REGION MILD NEUN BIS VIERZEHN  GRAD
# 2026-07-13 16:46:23,206 	Gloss Hypothesis:	MITTE REGION     IX     MILD NEUN BIS FUENFZEHN GRAD
# 2026-07-13 16:46:23,207 	Gloss Alignment :	S     S          S                    S
# 2026-07-13 16:46:23,207 ========================================================================================================================
# 2026-07-13 16:46:23,207 Logging Sequence: 20February_2011_Sunday_tagesschau-3166
# 2026-07-13 16:46:23,208 	Gloss Reference :	AMTAG REGION SCHNEE FLUSS REGEN
# 2026-07-13 16:46:23,208 	Gloss Hypothesis:	***** TAG    REGEN  FLUSS *****
# 2026-07-13 16:46:23,208 	Gloss Alignment :	D     S      S            D
# 2026-07-13 16:46:23,209 ========================================================================================================================
# 2026-07-13 16:46:23,209 Logging Sequence: 20June_2011_Monday_heute-6514
# 2026-07-13 16:46:23,210 	Gloss Reference :	DANN WETTER WECHSELHAFT
# 2026-07-13 16:46:23,210 	Gloss Hypothesis:	**** WETTER WECHSELHAFT
# 2026-07-13 16:46:23,210 	Gloss Alignment :	D
# 2026-07-13 16:46:23,211 ========================================================================================================================
# 2026-07-13 16:46:23,211 Logging Sequence: 10November_2009_Tuesday_tagesschau-7250
# 2026-07-13 16:46:23,211 	Gloss Reference :	DONNERSTAG NEBEL AUFLOESEN WOLKE BEWOELKT HABEN2
# 2026-07-13 16:46:23,212 	Gloss Hypothesis:	DONNERSTAG ***** KOMMEN    WOLKE ******** OST
# 2026-07-13 16:46:23,212 	Gloss Alignment :	           D     S               D        S
# 2026-07-13 16:46:23,212 ========================================================================================================================
# 2026-07-13 16:46:23,213 Logging Sequence: 24January_2013_Thursday_heute-7254
# 2026-07-13 16:46:23,213 	Gloss Reference :	ENDLICH SONNE ABER DEUTSCH KAUM
# 2026-07-13 16:46:23,213 	Gloss Hypothesis:	TEIL    SONNE ABER ******* BISSCHEN
# 2026-07-13 16:46:23,214 	Gloss Alignment :	S                  D       S
# 2026-07-13 16:46:23,214 ========================================================================================================================
# 2026-07-13 16:46:31,108 [Epoch: 002 Step: 00013600] Batch Recognition Loss:   1.269231 => Gls Tokens per Sec:     3159 || Lr: 0.000082
# 2026-07-13 16:46:44,948 Validation result at epoch   2, step    13600: duration: 13.8392s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.68922	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.74	(DEL: 17.05,	INS: 1.84,	SUB: 21.85)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:46:44,949 Logging Recognition and Translation Outputs
# 2026-07-13 16:46:44,949 ========================================================================================================================
# 2026-07-13 16:46:44,950 Logging Sequence: 07October_2012_Sunday_tagesschau-3026
# 2026-07-13 16:46:44,950 	Gloss Reference :	TAG KLAR STERN SEHEN KOENNEN FROST
# 2026-07-13 16:46:44,951 	Gloss Hypothesis:	TAG KLAR ***** SEHEN ******* FROST
# 2026-07-13 16:46:44,951 	Gloss Alignment :	         D           D
# 2026-07-13 16:46:44,951 ========================================================================================================================
# 2026-07-13 16:46:44,952 Logging Sequence: 23April_2010_Friday_tagesschau-3667
# 2026-07-13 16:46:44,952 	Gloss Reference :	NACHT MINUS DREI BIS PLUS  VIER NORD PLUS FUENF IX
# 2026-07-13 16:46:44,953 	Gloss Hypothesis:	NACHT MINUS DREI BIS MINUS VIER NORD PLUS FUENF **
# 2026-07-13 16:46:44,953 	Gloss Alignment :	                     S                          D
# 2026-07-13 16:46:44,953 ========================================================================================================================
# 2026-07-13 16:46:44,954 Logging Sequence: 30September_2012_Sunday_tagesschau-4038
# 2026-07-13 16:46:44,954 	Gloss Reference :	DONNERSTAG DEUTSCH LAND WECHSELHAFT UEBERWIEGEND   REGEN MOEGLICH STARK  WIND
# 2026-07-13 16:46:44,954 	Gloss Hypothesis:	DONNERSTAG ******* **** WECHSELHAFT HAUPTSAECHLICH REGEN KOENNEN  FRISCH WIND
# 2026-07-13 16:46:44,955 	Gloss Alignment :	           D       D                S                    S        S
# 2026-07-13 16:46:44,955 ========================================================================================================================
# 2026-07-13 16:46:44,955 Logging Sequence: 10December_2011_Saturday_tagesschau-5420
# 2026-07-13 16:46:44,956 	Gloss Reference :	AB MONTAG INKOMMEND WETTER WECHSELHAFT WIND
# 2026-07-13 16:46:44,956 	Gloss Hypothesis:	** MONTAG ********* WETTER WECHSELHAFT ****
# 2026-07-13 16:46:44,956 	Gloss Alignment :	D         D                            D
# 2026-07-13 16:46:44,957 ========================================================================================================================
# 2026-07-13 16:46:44,957 Logging Sequence: 28May_2010_Friday_tagesschau-7496
# 2026-07-13 16:46:44,957 	Gloss Reference :	HOCH KOMMEN OST KOMMEN ESBEDEUTET MORGEN FREUNDLICH WETTER
# 2026-07-13 16:46:44,958 	Gloss Hypothesis:	HOCH KOMMEN OST KOMMEN DANN       MORGEN FREUNDLICH WETTER
# 2026-07-13 16:46:44,958 	Gloss Alignment :	                       S
# 2026-07-13 16:46:44,958 ========================================================================================================================
# 2026-07-13 16:46:44,959 Logging Sequence: 29June_2010_Tuesday_tagesschau-7705
# 2026-07-13 16:46:44,959 	Gloss Reference :	HEUTE NACHT TEMPERATUR ELF  BIS ACHTZEHN GRAD
# 2026-07-13 16:46:44,960 	Gloss Hypothesis:	HEUTE NACHT TEMPERATUR EINS BIS ACHTZEHN GRAD
# 2026-07-13 16:46:44,960 	Gloss Alignment :	                       S
# 2026-07-13 16:46:44,960 ========================================================================================================================
# 2026-07-13 16:46:48,808 Epoch   2: Total Training Recognition Loss 282.20  Total Training Translation Loss -1.00
# 2026-07-13 16:46:48,809 EPOCH 3
# 2026-07-13 16:46:52,825 [Epoch: 003 Step: 00013700] Batch Recognition Loss:   1.033025 => Gls Tokens per Sec:     3393 || Lr: 0.000082
# 2026-07-13 16:47:06,490 Validation result at epoch   3, step    13700: duration: 13.6640s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.61309	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.42	(DEL: 16.38,	INS: 2.24,	SUB: 21.80)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:47:06,490 Logging Recognition and Translation Outputs
# 2026-07-13 16:47:06,491 ========================================================================================================================
# 2026-07-13 16:47:06,491 Logging Sequence: 22November_2010_Monday_heute-279
# 2026-07-13 16:47:06,492 	Gloss Reference :	IX KOENNEN GEFAHR GLATT BESONDERS MITTE REGION SUED DANN KALT
# 2026-07-13 16:47:06,492 	Gloss Hypothesis:	IX KOENNEN GEFAHR ***** BESONDERS ***** REGION SUED **** KALT
# 2026-07-13 16:47:06,493 	Gloss Alignment :	                  D               D                 D
# 2026-07-13 16:47:06,493 ========================================================================================================================
# 2026-07-13 16:47:06,493 Logging Sequence: 22January_2010_Friday_tagesschau-907
# 2026-07-13 16:47:06,494 	Gloss Reference :	TAG VIEL WOLKE NEBEL BLEIBEN TROCKEN IX SONNE MOEGLICH
# 2026-07-13 16:47:06,494 	Gloss Hypothesis:	TAG VIEL WOLKE NEBEL ******* TROCKEN IX SONNE MOEGLICH
# 2026-07-13 16:47:06,495 	Gloss Alignment :	                     D
# 2026-07-13 16:47:06,495 ========================================================================================================================
# 2026-07-13 16:47:06,495 Logging Sequence: 20October_2009_Tuesday_tagesschau-3595
# 2026-07-13 16:47:06,496 	Gloss Reference :	WIND WEHEN MAESSIG WEHEN
# 2026-07-13 16:47:06,496 	Gloss Hypothesis:	WIND WEHEN MAESSIG *****
# 2026-07-13 16:47:06,497 	Gloss Alignment :	                   D
# 2026-07-13 16:47:06,497 ========================================================================================================================
# 2026-07-13 16:47:06,497 Logging Sequence: 10August_2011_Wednesday_tagesschau-6303
# 2026-07-13 16:47:06,498 	Gloss Reference :	IMVERLAUF IMVERLAUF TEMPERATUR REGION
# 2026-07-13 16:47:06,498 	Gloss Hypothesis:	********* IMVERLAUF TEMPERATUR ******
# 2026-07-13 16:47:06,498 	Gloss Alignment :	D                              D
# 2026-07-13 16:47:06,499 ========================================================================================================================
# 2026-07-13 16:47:06,499 Logging Sequence: 12November_2009_Thursday_tagesschau-6770
# 2026-07-13 16:47:06,500 	Gloss Reference :	NORD MORGEN BEWOELKT REGION REGEN
# 2026-07-13 16:47:06,500 	Gloss Hypothesis:	NORD MORGEN WOLKE    REGION REGEN
# 2026-07-13 16:47:06,500 	Gloss Alignment :	            S
# 2026-07-13 16:47:06,500 ========================================================================================================================
# 2026-07-13 16:47:06,501 Logging Sequence: 15July_2011_Friday_tagesschau-8726
# 2026-07-13 16:47:06,501 	Gloss Reference :	IX MORGEN NEUNZEHN   GRAD REGION SIEBEN ZWANZIG GRAD
# 2026-07-13 16:47:06,502 	Gloss Hypothesis:	IX MORGEN DONNERSTAG GRAD REGION SIEBEN ZWANZIG GRAD
# 2026-07-13 16:47:06,502 	Gloss Alignment :	          S
# 2026-07-13 16:47:06,502 ========================================================================================================================
# 2026-07-13 16:47:12,743 [Epoch: 003 Step: 00013800] Batch Recognition Loss:   1.461665 => Gls Tokens per Sec:     4007 || Lr: 0.000082
# 2026-07-13 16:47:26,525 Validation result at epoch   3, step    13800: duration: 13.7809s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.79764	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.07	(DEL: 14.91,	INS: 3.01,	SUB: 22.15)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:47:26,526 Logging Recognition and Translation Outputs
# 2026-07-13 16:47:26,526 ========================================================================================================================
# 2026-07-13 16:47:26,526 Logging Sequence: 25February_2011_Friday_tagesschau-575
# 2026-07-13 16:47:26,527 	Gloss Reference :	DIENSTAG RUHIG TROCKEN WETTER
# 2026-07-13 16:47:26,527 	Gloss Hypothesis:	WENN     RUHIG TROCKEN WETTER
# 2026-07-13 16:47:26,528 	Gloss Alignment :	S
# 2026-07-13 16:47:26,528 ========================================================================================================================
# 2026-07-13 16:47:26,529 Logging Sequence: 27August_2009_Thursday_tagesschau-3285
# 2026-07-13 16:47:26,529 	Gloss Reference :	NORD SCHAUER
# 2026-07-13 16:47:26,530 	Gloss Hypothesis:	**** OST
# 2026-07-13 16:47:26,530 	Gloss Alignment :	D    S
# 2026-07-13 16:47:26,531 ========================================================================================================================
# 2026-07-13 16:47:26,531 Logging Sequence: 24January_2011_Monday_tagesschau-3720
# 2026-07-13 16:47:26,532 	Gloss Reference :	WIND WEHEN FRISCH KOMMEN HOCH   STURM
# 2026-07-13 16:47:26,532 	Gloss Hypothesis:	WIND ***** FRISCH WEHEN  SCHWER STURM
# 2026-07-13 16:47:26,533 	Gloss Alignment :	     D            S      S
# 2026-07-13 16:47:26,533 ========================================================================================================================
# 2026-07-13 16:47:26,533 Logging Sequence: 29September_2011_Thursday_heute-4235
# 2026-07-13 16:47:26,534 	Gloss Reference :	SCHOEN ABEND possEUCH MACHEN GUT possEUCH
# 2026-07-13 16:47:26,535 	Gloss Hypothesis:	SCHOEN ABEND possEUCH ****** GUT possEUCH
# 2026-07-13 16:47:26,535 	Gloss Alignment :	                      D
# 2026-07-13 16:47:26,535 ========================================================================================================================
# 2026-07-13 16:47:26,536 Logging Sequence: 24October_2009_Saturday_tagesschau-4285
# 2026-07-13 16:47:26,537 	Gloss Reference :	**** TAG     DANN WEST **** FREUNDLICH SONNE DABEI
# 2026-07-13 16:47:26,537 	Gloss Hypothesis:	NORD SPAETER DANN WEST WALD MEISTENS   SONNE DABEI
# 2026-07-13 16:47:26,538 	Gloss Alignment :	I    S                 I    S
# 2026-07-13 16:47:26,538 ========================================================================================================================
# 2026-07-13 16:47:26,539 Logging Sequence: 24July_2011_Sunday_tagesschau-6621
# 2026-07-13 16:47:26,539 	Gloss Reference :	DARUNTER  TAG IMVERLAUF MEHR WARM
# 2026-07-13 16:47:26,540 	Gloss Hypothesis:	INKOMMEND TAG MITTAG    MEHR ****
# 2026-07-13 16:47:26,540 	Gloss Alignment :	S             S              D
# 2026-07-13 16:47:26,540 ========================================================================================================================
# 2026-07-13 16:47:30,132 Epoch   3: Total Training Recognition Loss 275.99  Total Training Translation Loss -1.00
# 2026-07-13 16:47:30,133 EPOCH 4
# 2026-07-13 16:47:31,968 [Epoch: 004 Step: 00013900] Batch Recognition Loss:   1.348205 => Gls Tokens per Sec:     4486 || Lr: 0.000082
# 2026-07-13 16:47:46,341 Hooray! New best validation result [eval_metric]!
# 2026-07-13 16:47:46,342 Saving new checkpoint.
# 2026-07-13 16:47:46,401 Validation result at epoch   4, step    13900: duration: 14.4321s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.89402	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 39.81	(DEL: 14.43,	INS: 2.77,	SUB: 22.60)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:47:46,402 Logging Recognition and Translation Outputs
# 2026-07-13 16:47:46,402 ========================================================================================================================
# 2026-07-13 16:47:46,402 Logging Sequence: 04April_2011_Monday_heute-965
# 2026-07-13 16:47:46,403 	Gloss Reference :	MORGEN MEHR WARM IX ALS HEUTE
# 2026-07-13 16:47:46,404 	Gloss Hypothesis:	MORGEN MEHR WARM ** *** JETZT
# 2026-07-13 16:47:46,404 	Gloss Alignment :	                 D  D   S
# 2026-07-13 16:47:46,404 ========================================================================================================================
# 2026-07-13 16:47:46,405 Logging Sequence: 29October_2009_Thursday_tagesschau-1011
# 2026-07-13 16:47:46,405 	Gloss Reference :	JETZT WETTER WIEAUSSEHEN MORGEN **** DREISSIG OKTOBER
# 2026-07-13 16:47:46,406 	Gloss Hypothesis:	JETZT WETTER WIEAUSSEHEN MORGEN EINS ZWANZIG  OKTOBER
# 2026-07-13 16:47:46,406 	Gloss Alignment :	                                I    S
# 2026-07-13 16:47:46,407 ========================================================================================================================
# 2026-07-13 16:47:46,407 Logging Sequence: 23July_2011_Saturday_tagesschau-5498
# 2026-07-13 16:47:46,408 	Gloss Reference :	SPAETER REGEN UEBERALL REGION
# 2026-07-13 16:47:46,408 	Gloss Hypothesis:	SPAETER MEHR  LEICHT   REGION
# 2026-07-13 16:47:46,409 	Gloss Alignment :	        S     S
# 2026-07-13 16:47:46,409 ========================================================================================================================
# 2026-07-13 16:47:46,409 Logging Sequence: 18November_2009_Wednesday_tagesschau-5586
# 2026-07-13 16:47:46,410 	Gloss Reference :	WENN NEBEL negHABEN FREUNDLICH
# 2026-07-13 16:47:46,410 	Gloss Hypothesis:	WENN NEBEL KUEHL    FREUNDLICH
# 2026-07-13 16:47:46,411 	Gloss Alignment :	           S
# 2026-07-13 16:47:46,411 ========================================================================================================================
# 2026-07-13 16:47:46,412 Logging Sequence: 24January_2011_Monday_heute-6980
# 2026-07-13 16:47:46,412 	Gloss Reference :	MORGEN MEISTENS ZWEI BIS SECHS GRAD ABER BAYERN REGION BISSCHEN KALT MITTE  REGION AUCH
# 2026-07-13 16:47:46,413 	Gloss Hypothesis:	MORGEN ******** ZWEI BIS SECHS GRAD AB   BAYERN REGION ******** **** SCHNEE REGION AUCH
# 2026-07-13 16:47:46,413 	Gloss Alignment :	       D                            S                  D        D    S
# 2026-07-13 16:47:46,414 ========================================================================================================================
# 2026-07-13 16:47:46,414 Logging Sequence: 16July_2011_Saturday_tagesschau-7524
# 2026-07-13 16:47:46,415 	Gloss Reference :	NACHT KOMMEN REGEN STARK OST SUEDOST KLAR SEHEN STERN    KOENNEN
# 2026-07-13 16:47:46,415 	Gloss Hypothesis:	WEST  KOMMEN REGEN STARK OST SUEDOST KLAR IX    GEWITTER KOENNEN
# 2026-07-13 16:47:46,415 	Gloss Alignment :	S                                         S     S
# 2026-07-13 16:47:46,416 ========================================================================================================================
# 2026-07-13 16:47:51,888 [Epoch: 004 Step: 00014000] Batch Recognition Loss:   1.300683 => Gls Tokens per Sec:     4542 || Lr: 0.000082
# 2026-07-13 16:48:05,455 Validation result at epoch   4, step    14000: duration: 13.5658s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.50881	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.66	(DEL: 16.92,	INS: 2.19,	SUB: 21.56)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:48:05,456 Logging Recognition and Translation Outputs
# 2026-07-13 16:48:05,456 ========================================================================================================================
# 2026-07-13 16:48:05,456 Logging Sequence: 09August_2009_Sunday_tagesschau-1179
# 2026-07-13 16:48:05,457 	Gloss Reference :	MORGEN WEST TIEF KOMMEN RICHTUNG OST AUFZIEHEN
# 2026-07-13 16:48:05,457 	Gloss Hypothesis:	MORGEN WEST TIEF KOMMEN ******** OST *********
# 2026-07-13 16:48:05,458 	Gloss Alignment :	                        D            D
# 2026-07-13 16:48:05,458 ========================================================================================================================
# 2026-07-13 16:48:05,458 Logging Sequence: 10August_2010_Tuesday_heute-1455
# 2026-07-13 16:48:05,459 	Gloss Reference :	OST REGION SONNE MEHR WARM MAXIMAL SECHS ZWANZIG SUED MAXIMAL SIEBEN ZWANZIG GRAD
# 2026-07-13 16:48:05,459 	Gloss Hypothesis:	OST REGION SONNE MEHR WARM MAXIMAL ***** ZWANZIG SUED MAXIMAL SIEBEN ZWANZIG ****
# 2026-07-13 16:48:05,460 	Gloss Alignment :	                                   D                                         D
# 2026-07-13 16:48:05,460 ========================================================================================================================
# 2026-07-13 16:48:05,460 Logging Sequence: 12November_2009_Thursday_tagesschau-6771
# 2026-07-13 16:48:05,461 	Gloss Reference :	SUED ******** MEISTENS TROCKEN EINIGE WOLKE NEBEL MAL      SONNE
# 2026-07-13 16:48:05,461 	Gloss Hypothesis:	SUED SUEDWEST MEISTENS TROCKEN SONNE  WOLKE NEBEL MANCHMAL SONNE
# 2026-07-13 16:48:05,461 	Gloss Alignment :	     I                         S                  S
# 2026-07-13 16:48:05,462 ========================================================================================================================
# 2026-07-13 16:48:05,462 Logging Sequence: 13July_2009_Monday_tagesschau-7513
# 2026-07-13 16:48:05,463 	Gloss Reference :	REGION SONNE SCHAUER GEWITTER SUED IX   ENORM ***** HAGEL STARK REGEN STURM
# 2026-07-13 16:48:05,463 	Gloss Hypothesis:	REGION ***** SCHAUER GEWITTER SUED MEHR ENORM KUEHL TIEF  STARK REGEN STURM
# 2026-07-13 16:48:05,463 	Gloss Alignment :	       D                           S          I     S
# 2026-07-13 16:48:05,464 ========================================================================================================================
# 2026-07-13 16:48:05,464 Logging Sequence: 13May_2010_Thursday_tagesschau-7916
# 2026-07-13 16:48:05,464 	Gloss Reference :	JETZT WETTER MORGEN FREITAG VIERZEHN MAI
# 2026-07-13 16:48:05,465 	Gloss Hypothesis:	JETZT WETTER ****** FREITAG ******** ***
# 2026-07-13 16:48:05,465 	Gloss Alignment :	             D              D        D
# 2026-07-13 16:48:05,466 ========================================================================================================================
# 2026-07-13 16:48:05,466 Logging Sequence: 27May_2011_Friday_tagesschau-8133
# 2026-07-13 16:48:05,466 	Gloss Reference :	DIENSTAG KOMMEN REGEN KOENNEN GEWITTER UNWETTER REGEN HAGEL KRAEFTIG WIND KOENNEN
# 2026-07-13 16:48:05,467 	Gloss Hypothesis:	DIENSTAG KOMMEN REGEN KOENNEN ******** WIND     REGEN ***** ******** WIND KOENNEN
# 2026-07-13 16:48:05,467 	Gloss Alignment :	                              D        S              D     D
# 2026-07-13 16:48:05,467 ========================================================================================================================
# 2026-07-13 16:48:10,983 Epoch   4: Total Training Recognition Loss 271.27  Total Training Translation Loss -1.00
# 2026-07-13 16:48:10,984 EPOCH 5
# 2026-07-13 16:48:12,039 [Epoch: 005 Step: 00014100] Batch Recognition Loss:   1.418329 => Gls Tokens per Sec:     2891 || Lr: 0.000082
# 2026-07-13 16:48:25,909 Validation result at epoch   5, step    14100: duration: 13.8691s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 37.06373	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.15	(DEL: 14.19,	INS: 2.61,	SUB: 23.35)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:48:25,910 Logging Recognition and Translation Outputs
# 2026-07-13 16:48:25,910 ========================================================================================================================
# 2026-07-13 16:48:25,910 Logging Sequence: 30January_2013_Wednesday_tagesschau-477
# 2026-07-13 16:48:25,911 	Gloss Reference :	SONNTAG WAHRSCHEINLICH FREUNDLICH IMVERLAUF WEST SCHNEE SCHNEIEN REGEN
# 2026-07-13 16:48:25,911 	Gloss Hypothesis:	SONNTAG WEHEN          FREUNDLICH IMVERLAUF WEST SCHNEE SCHNEIEN REGEN
# 2026-07-13 16:48:25,912 	Gloss Alignment :	        S
# 2026-07-13 16:48:25,912 ========================================================================================================================
# 2026-07-13 16:48:25,912 Logging Sequence: 23April_2010_Friday_tagesschau-3668
# 2026-07-13 16:48:25,913 	Gloss Reference :	MORGEN ZEHN BIS FUENFZEHN REGION SECHSZEHN BIS   DREI ZWANZIG
# 2026-07-13 16:48:25,913 	Gloss Hypothesis:	MORGEN ZEHN BIS FUENFZEHN REGION ********* FLUSS DREI *******
# 2026-07-13 16:48:25,913 	Gloss Alignment :	                                 D         S          D
# 2026-07-13 16:48:25,914 ========================================================================================================================
# 2026-07-13 16:48:25,914 Logging Sequence: 28September_2009_Monday_tagesschau-4680
# 2026-07-13 16:48:25,914 	Gloss Reference :	TAG VIERZEHN NORD REGEN  EINS ZWANZIG FLUSS
# 2026-07-13 16:48:25,915 	Gloss Hypothesis:	TAG ******** NORD SCHNEE EINS ZWANZIG FLUSS
# 2026-07-13 16:48:25,915 	Gloss Alignment :	    D             S
# 2026-07-13 16:48:25,915 ========================================================================================================================
# 2026-07-13 16:48:25,916 Logging Sequence: 29November_2011_Tuesday_tagesschau-5619
# 2026-07-13 16:48:25,916 	Gloss Reference :	NACHT SECHS GRAD SEE MINUS DREI ****** FLUSS
# 2026-07-13 16:48:25,917 	Gloss Hypothesis:	NACHT EINS  GRAD *** MINUS DREI ZWOELF REGION
# 2026-07-13 16:48:25,917 	Gloss Alignment :	      S          D              I      S
# 2026-07-13 16:48:25,917 ========================================================================================================================
# 2026-07-13 16:48:25,918 Logging Sequence: 19January_2011_Wednesday_tagesschau-7068
# 2026-07-13 16:48:25,918 	Gloss Reference :	JETZT WETTER VORAUS INFORMIEREN MORGEN DONNERSTAG ZWANZIG JANUAR
# 2026-07-13 16:48:25,918 	Gloss Hypothesis:	JETZT WETTER VORAUS *********** MORGEN DONNERSTAG ZWANZIG JANUAR
# 2026-07-13 16:48:25,919 	Gloss Alignment :	                    D
# 2026-07-13 16:48:25,919 ========================================================================================================================
# 2026-07-13 16:48:25,919 Logging Sequence: 27June_2010_Sunday_tagesschau-7386
# 2026-07-13 16:48:25,920 	Gloss Reference :	DIENSTAG MITTWOCH TIEF KOMMEN MOEGLICH REGEN GEWITTER
# 2026-07-13 16:48:25,920 	Gloss Hypothesis:	DIENSTAG MITTWOCH TIEF KOMMEN MOEGLICH REGEN GEWITTER
# 2026-07-13 16:48:25,921 	Gloss Alignment :
# 2026-07-13 16:48:25,921 ========================================================================================================================
# 2026-07-13 16:48:34,057 [Epoch: 005 Step: 00014200] Batch Recognition Loss:   1.192389 => Gls Tokens per Sec:     3077 || Lr: 0.000082
# 2026-07-13 16:48:47,662 Validation result at epoch   5, step    14200: duration: 13.6038s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 36.96178	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.02	(DEL: 14.62,	INS: 2.80,	SUB: 22.60)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:48:47,663 Logging Recognition and Translation Outputs
# 2026-07-13 16:48:47,663 ========================================================================================================================
# 2026-07-13 16:48:47,664 Logging Sequence: 06July_2009_Monday_tagesschau-2109
# 2026-07-13 16:48:47,664 	Gloss Reference :	***** MORGEN WERT   EIFEL ACHTZEHN BIS SECHS ZWANZIG LAND
# 2026-07-13 16:48:47,665 	Gloss Hypothesis:	MITTE MORGEN WEITER ALPEN ACHTZEHN BIS SECHS ZWANZIG REGION
# 2026-07-13 16:48:47,665 	Gloss Alignment :	I            S      S                                S
# 2026-07-13 16:48:47,665 ========================================================================================================================
# 2026-07-13 16:48:47,666 Logging Sequence: 31May_2011_Tuesday_tagesschau-4294
# 2026-07-13 16:48:47,666 	Gloss Reference :	DEUTSCH WETTER DIENST WARNUNG
# 2026-07-13 16:48:47,667 	Gloss Hypothesis:	NORD    MEHR   ANFANG WARNUNG
# 2026-07-13 16:48:47,667 	Gloss Alignment :	S       S      S
# 2026-07-13 16:48:47,667 ========================================================================================================================
# 2026-07-13 16:48:47,668 Logging Sequence: 28September_2009_Monday_tagesschau-4680
# 2026-07-13 16:48:47,668 	Gloss Reference :	TAG VIERZEHN NORD REGEN  EINS ZWANZIG FLUSS
# 2026-07-13 16:48:47,669 	Gloss Hypothesis:	TAG ******** NORD SCHNEE EINS ZWANZIG FLUSS
# 2026-07-13 16:48:47,669 	Gloss Alignment :	    D             S
# 2026-07-13 16:48:47,669 ========================================================================================================================
# 2026-07-13 16:48:47,670 Logging Sequence: 23September_2009_Wednesday_tagesschau-7593
# 2026-07-13 16:48:47,670 	Gloss Reference :	SONNTAG SCHEINEN ALPEN AUCH SCHAUER MOEGLICH
# 2026-07-13 16:48:47,671 	Gloss Hypothesis:	SONNTAG WOLKE    ALPEN AUCH SCHAUER MOEGLICH
# 2026-07-13 16:48:47,671 	Gloss Alignment :	        S
# 2026-07-13 16:48:47,672 ========================================================================================================================
# 2026-07-13 16:48:47,672 Logging Sequence: 03September_2010_Friday_tagesschau-8423
# 2026-07-13 16:48:47,673 	Gloss Reference :	KUEHL KOMMEN
# 2026-07-13 16:48:47,673 	Gloss Hypothesis:	KUEHL ******
# 2026-07-13 16:48:47,673 	Gloss Alignment :	      D
# 2026-07-13 16:48:47,674 ========================================================================================================================
# 2026-07-13 16:48:47,674 Logging Sequence: 23March_2011_Wednesday_tagesschau-8751
# 2026-07-13 16:48:47,675 	Gloss Reference :	NORDOST WIEDER WOLKE ABER SONST   NUR BISSCHEN WOLKE
# 2026-07-13 16:48:47,675 	Gloss Hypothesis:	NORDOST OST    WOLKE **** NORDOST NUR ******** WENIG
# 2026-07-13 16:48:47,676 	Gloss Alignment :	        S            D    S           D        S
# 2026-07-13 16:48:47,676 ========================================================================================================================
# 2026-07-13 16:48:55,530 [Epoch: 005 Step: 00014300] Batch Recognition Loss:   1.652509 => Gls Tokens per Sec:     3138 || Lr: 0.000082
# 2026-07-13 16:49:09,089 Validation result at epoch   5, step    14300: duration: 13.5582s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 37.08967	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.74	(DEL: 15.50,	INS: 2.72,	SUB: 22.52)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:49:09,090 Logging Recognition and Translation Outputs
# 2026-07-13 16:49:09,090 ========================================================================================================================
# 2026-07-13 16:49:09,090 Logging Sequence: 21August_2011_Sunday_tagesschau-265
# 2026-07-13 16:49:09,091 	Gloss Reference :	MITTE REGION WOLKE MORGEN KOENNEN REGEN GEWITTER
# 2026-07-13 16:49:09,091 	Gloss Hypothesis:	WENN  KUESTE WOLKE ****** HEUTE   REGEN GEWITTER
# 2026-07-13 16:49:09,092 	Gloss Alignment :	S     S            D      S
# 2026-07-13 16:49:09,092 ========================================================================================================================
# 2026-07-13 16:49:09,093 Logging Sequence: 04May_2010_Tuesday_heute-453
# 2026-07-13 16:49:09,093 	Gloss Reference :	HOCH NORD SONNE DESHALB GRENZE HOCH TIEF
# 2026-07-13 16:49:09,093 	Gloss Hypothesis:	HOCH NORD SONNE DESHALB ****** HOCH ****
# 2026-07-13 16:49:09,094 	Gloss Alignment :	                        D           D
# 2026-07-13 16:49:09,094 ========================================================================================================================
# 2026-07-13 16:49:09,094 Logging Sequence: 02October_2012_Tuesday_heute-3494
# 2026-07-13 16:49:09,095 	Gloss Reference :	HEUTE NACHT negKAUM NUR NORDWEST BISSCHEN REGEN SONST REGION RUHIG
# 2026-07-13 16:49:09,095 	Gloss Hypothesis:	HEUTE NACHT AUCH    NUR NORDWEST IX       REGEN SONST REGION *****
# 2026-07-13 16:49:09,096 	Gloss Alignment :	            S                    S                           D
# 2026-07-13 16:49:09,096 ========================================================================================================================
# 2026-07-13 16:49:09,096 Logging Sequence: 20June_2011_Monday_heute-6514
# 2026-07-13 16:49:09,097 	Gloss Reference :	DANN WETTER WECHSELHAFT
# 2026-07-13 16:49:09,097 	Gloss Hypothesis:	**** WETTER WECHSELHAFT
# 2026-07-13 16:49:09,097 	Gloss Alignment :	D
# 2026-07-13 16:49:09,098 ========================================================================================================================
# 2026-07-13 16:49:09,098 Logging Sequence: 24January_2011_Monday_heute-6984
# 2026-07-13 16:49:09,098 	Gloss Reference :	MITTWOCH SONNE NICHT NUR WEST SCHNEE REGEN MISCHUNG DANN BEISEITE
# 2026-07-13 16:49:09,099 	Gloss Hypothesis:	MITTWOCH SONNE NEUN  NUR WEST ****** REGEN KOMMEN   DANN MAXIMAL
# 2026-07-13 16:49:09,099 	Gloss Alignment :	               S              D            S             S
# 2026-07-13 16:49:09,099 ========================================================================================================================
# 2026-07-13 16:49:09,100 Logging Sequence: 25January_2013_Friday_tagesschau-7815
# 2026-07-13 16:49:09,100 	Gloss Reference :	MORGEN TEIL UEBERWIEGEND WOLKE TEIL SONNE OST UEBERWIEGEND MEHR SONNE DABEI
# 2026-07-13 16:49:09,101 	Gloss Hypothesis:	****** TEIL ************ WOLKE TEIL SONNE OST ************ MEHR SONNE *****
# 2026-07-13 16:49:09,101 	Gloss Alignment :	D           D                                 D                       D
# 2026-07-13 16:49:09,101 ========================================================================================================================
# 2026-07-13 16:49:10,004 Epoch   5: Total Training Recognition Loss 266.82  Total Training Translation Loss -1.00
# 2026-07-13 16:49:10,063 Periodic checkpoint saved at epoch 5, step 14310 -> ../../runs/forward_warm_control_002/final/resume.ckpt
# 2026-07-13 16:49:10,064 EPOCH 6
# 2026-07-13 16:49:15,587 [Epoch: 006 Step: 00014400] Batch Recognition Loss:   1.177899 => Gls Tokens per Sec:     4096 || Lr: 0.000082
# ...
# 2026-07-13 16:54:53,063 ========================================================================================================================
# 2026-07-13 16:54:53,063 Logging Sequence: 24January_2010_Sunday_tagesschau-8710
# 2026-07-13 16:54:53,064 	Gloss Reference :	SUED SCHWACH WEHEN IX   MAESSIG WEHEN
# 2026-07-13 16:54:53,064 	Gloss Hypothesis:	SUED SCHWACH WEHEN NORD MAESSIG WEHEN
# 2026-07-13 16:54:53,065 	Gloss Alignment :	                   S
# 2026-07-13 16:54:53,065 ========================================================================================================================
# 2026-07-13 16:54:57,789 Epoch  13: Total Training Recognition Loss 238.05  Total Training Translation Loss -1.00
# 2026-07-13 16:54:57,789 EPOCH 14
# 2026-07-13 16:54:58,588 [Epoch: 014 Step: 00016100] Batch Recognition Loss:   0.825228 => Gls Tokens per Sec:     4437 || Lr: 0.000065
# 2026-07-13 16:55:12,197 Validation result at epoch  14, step    16100: duration: 13.6079s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 38.34266	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 41.06	(DEL: 15.69,	INS: 2.93,	SUB: 22.44)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:55:12,197 Logging Recognition and Translation Outputs
# 2026-07-13 16:55:12,198 ========================================================================================================================
# 2026-07-13 16:55:12,198 Logging Sequence: 22April_2010_Thursday_heute-2120
# 2026-07-13 16:55:12,199 	Gloss Reference :	MORGEN SONNE UEBERALL KUESTE REGION WOLKE ****** MOEGLICH REGEN negVIEL
# 2026-07-13 16:55:12,199 	Gloss Hypothesis:	MORGEN SONNE HIMMEL   KUESTE REGION WOLKE REGION MOEGLICH REGEN VIEL
# 2026-07-13 16:55:12,199 	Gloss Alignment :	             S                            I                     S
# 2026-07-13 16:55:12,200 ========================================================================================================================
# 2026-07-13 16:55:12,200 Logging Sequence: 23August_2010_Monday_tagesschau-4430
# 2026-07-13 16:55:12,200 	Gloss Reference :	DAZU KOENNEN  GEWITTER
# 2026-07-13 16:55:12,201 	Gloss Hypothesis:	**** IMMOMENT GEWITTER
# 2026-07-13 16:55:12,201 	Gloss Alignment :	D    S
# 2026-07-13 16:55:12,202 ========================================================================================================================
# 2026-07-13 16:55:12,202 Logging Sequence: 26April_2010_Monday_tagesschau-7271
# 2026-07-13 16:55:12,202 	Gloss Reference :	TEMPERATUR INKOMMEND MEHR
# 2026-07-13 16:55:12,203 	Gloss Hypothesis:	TEMPERATUR ********* SUED
# 2026-07-13 16:55:12,203 	Gloss Alignment :	           D         S
# 2026-07-13 16:55:12,203 ========================================================================================================================
# 2026-07-13 16:55:12,204 Logging Sequence: 23January_2011_Sunday_tagesschau-7834
# 2026-07-13 16:55:12,204 	Gloss Reference :	AUCH DIENSTAG WOLKE MEHR REGEN ODER SCHNEE
# 2026-07-13 16:55:12,205 	Gloss Hypothesis:	AUCH TIEF     WOLKE MEHR REGEN ODER SCHNEE
# 2026-07-13 16:55:12,205 	Gloss Alignment :	     S
# 2026-07-13 16:55:12,205 ========================================================================================================================
# 2026-07-13 16:55:12,205 Logging Sequence: 12December_2011_Monday_tagesschau-8281
# 2026-07-13 16:55:12,206 	Gloss Reference :	MORGEN DREI GRAD REGION BAYERN WALD IX ZWOELF KOELN
# 2026-07-13 16:55:12,206 	Gloss Hypothesis:	MORGEN **** GRAD IX     BAYERN WALD ** ****** MEISTENS
# 2026-07-13 16:55:12,207 	Gloss Alignment :	       D         S                  D  D      S
# 2026-07-13 16:55:12,207 ========================================================================================================================
# 2026-07-13 16:55:12,207 Logging Sequence: 23March_2011_Wednesday_tagesschau-8751
# 2026-07-13 16:55:12,208 	Gloss Reference :	NORDOST WIEDER WOLKE ABER SONST NUR BISSCHEN WOLKE
# 2026-07-13 16:55:12,208 	Gloss Hypothesis:	NORDOST ****** WOLKE **** SONST NUR BISSCHEN *****
# 2026-07-13 16:55:12,208 	Gloss Alignment :	        D            D                       D
# 2026-07-13 16:55:12,209 ========================================================================================================================
# 2026-07-13 16:55:17,712 [Epoch: 014 Step: 00016200] Batch Recognition Loss:   1.301522 => Gls Tokens per Sec:     4521 || Lr: 0.000052
# 2026-07-13 16:55:31,620 Validation result at epoch  14, step    16200: duration: 13.9081s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 38.01332	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.80	(DEL: 15.21,	INS: 2.51,	SUB: 23.08)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:55:31,621 Logging Recognition and Translation Outputs
# 2026-07-13 16:55:31,622 ========================================================================================================================
# 2026-07-13 16:55:31,622 Logging Sequence: 20November_2011_Sunday_tagesschau-536
# 2026-07-13 16:55:31,623 	Gloss Reference :	MISCHUNG NEBEL HOCH NEBEL SONNE BLEIBEN
# 2026-07-13 16:55:31,623 	Gloss Hypothesis:	MISCHUNG NEBEL HOCH NEBEL SONNE BLEIBEN
# 2026-07-13 16:55:31,623 	Gloss Alignment :
# 2026-07-13 16:55:31,624 ========================================================================================================================
# 2026-07-13 16:55:31,624 Logging Sequence: 03July_2009_Friday_tagesschau-2003
# 2026-07-13 16:55:31,624 	Gloss Reference :	*** ***** GERADE RHEINPFALZ SAARLAND NORDRHEINWESTFALEN GEWITTER
# 2026-07-13 16:55:31,625 	Gloss Hypothesis:	TAG FLUSS REGION VIERZEHN   REGION   KOMMEN             GEWITTER
# 2026-07-13 16:55:31,625 	Gloss Alignment :	I   I     S      S          S        S
# 2026-07-13 16:55:31,626 ========================================================================================================================
# 2026-07-13 16:55:31,626 Logging Sequence: 30November_2010_Tuesday_tagesschau-4620
# 2026-07-13 16:55:31,626 	Gloss Reference :	KUESTE HEUTE NACHT SCHNEE REGION WOLKE BISSCHEN TROCKEN
# 2026-07-13 16:55:31,627 	Gloss Hypothesis:	KUESTE ***** NACHT SCHNEE REGION WOLKE ******** IX
# 2026-07-13 16:55:31,627 	Gloss Alignment :	       D                               D        S
# 2026-07-13 16:55:31,627 ========================================================================================================================
# 2026-07-13 16:55:31,628 Logging Sequence: 26March_2011_Saturday_tagesschau-5731
# 2026-07-13 16:55:31,628 	Gloss Reference :	DIENSTAG UEBERALL VIEL SONNE WOLKE LOCKER TROCKEN
# 2026-07-13 16:55:31,629 	Gloss Hypothesis:	DIENSTAG REGION   MEHR SONNE WOLKE LANG   OST
# 2026-07-13 16:55:31,629 	Gloss Alignment :	         S        S                S      S
# 2026-07-13 16:55:31,629 ========================================================================================================================
# 2026-07-13 16:55:31,630 Logging Sequence: 16December_2011_Friday_tagesschau-6529
# 2026-07-13 16:55:31,630 	Gloss Reference :	KOMMEN IX    KALT KOMMEN IX   SCHNEE GLATT KOENNEN
# 2026-07-13 16:55:31,630 	Gloss Hypothesis:	KOMMEN NACHT KALT KOMMEN DANN SCHNEE ***** KOENNEN
# 2026-07-13 16:55:31,631 	Gloss Alignment :	       S                 S           D
# 2026-07-13 16:55:31,631 ========================================================================================================================
# 2026-07-13 16:55:31,631 Logging Sequence: 06October_2012_Saturday_tagesschau-8730
# 2026-07-13 16:55:31,632 	Gloss Reference :	MORGEN DEUTSCH LAND IX     TIEF KOMMEN KUEHL KOMMEN
# 2026-07-13 16:55:31,632 	Gloss Hypothesis:	MORGEN DEUTSCH LAND KOMMEN TIEF KOMMEN SONST REGION
# 2026-07-13 16:55:31,632 	Gloss Alignment :	                    S                  S     S
# 2026-07-13 16:55:31,633 ========================================================================================================================
# 2026-07-13 16:55:37,027 [Epoch: 014 Step: 00016300] Batch Recognition Loss:   0.872286 => Gls Tokens per Sec:     4572 || Lr: 0.000052
# 2026-07-13 16:55:51,250 Validation result at epoch  14, step    16300: duration: 14.2227s
# 	Recognition Beam Size: 1	Translation Beam Size: -1	Translation Beam Alpha: -1
# 	Recognition Loss: 38.70236	Translation Loss: -1.00000	PPL: -1.00000
# 	Eval Metric: WER
# 	WER 40.55	(DEL: 13.29,	INS: 3.20,	SUB: 24.07)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 16:55:51,251 Logging Recognition and Translation Outputs
# 2026-07-13 16:55:51,251 ========================================================================================================================
# 2026-07-13 16:55:51,252 Logging Sequence: 25November_2010_Thursday_tagesschau-2530
# 2026-07-13 16:55:51,252 	Gloss Reference :	NORDWEST SCHNEE SCHAUER VERSCHWINDEN
# 2026-07-13 16:55:51,253 	Gloss Hypothesis:	NORDWEST SCHNEE SCHAUER VERSCHWINDEN
# 2026-07-13 16:55:51,253 	Gloss Alignment :
# 2026-07-13 16:55:51,254 ========================================================================================================================
# 2026-07-13 16:55:51,254 Logging Sequence: 23February_2011_Wednesday_heute-3780
# 2026-07-13 16:55:51,255 	Gloss Reference :	SCHOEN ABEND MACHEN possEUCH GUT
# 2026-07-13 16:55:51,255 	Gloss Hypothesis:	SCHOEN ABEND ****** possEUCH GUT
# 2026-07-13 16:55:51,255 	Gloss Alignment :	             D
# 2026-07-13 16:55:51,256 ========================================================================================================================
# 2026-07-13 16:55:51,256 Logging Sequence: 16February_2010_Tuesday_tagesschau-6098
# 2026-07-13 16:55:51,257 	Gloss Reference :	WEST TAG  REGEN IX KOENNEN SCHNEE REGEN KALT      FROST OST WOLKE  BEWOELKT FREUNDLICH
# 2026-07-13 16:55:51,258 	Gloss Hypothesis:	WEST TEIL REGEN ** KOENNEN SCHNEE REGEN GEFRIEREN BODEN OST REGION WOLKE    FREUNDLICH
# 2026-07-13 16:55:51,258 	Gloss Alignment :	     S          D                       S         S         S      S
# 2026-07-13 16:55:51,258 ========================================================================================================================
# 2026-07-13 16:55:51,259 Logging Sequence: 20September_2010_Monday_tagesschau-7029
# 2026-07-13 16:55:51,259 	Gloss Reference :	BESONDERS NAH        FLUSS NEBEL   FELD
# 2026-07-13 16:55:51,260 	Gloss Hypothesis:	********* WOCHENENDE POLEN BLEIBEN KOMMEN
# 2026-07-13 16:55:51,260 	Gloss Alignment :	D         S          S     S       S
# 2026-07-13 16:55:51,261 ========================================================================================================================
# 2026-07-13 16:55:51,261 Logging Sequence: 02June_2010_Wednesday_tagesschau-7160
# 2026-07-13 16:55:51,262 	Gloss Reference :	HEUTE NACHT SECHS BIS DREIZEHN GRAD TAG TEMPERATUR STEIGEN ZEHN GRAD ALPEN BIS FUENF ZWANZIG GRAD WEST
# 2026-07-13 16:55:51,262 	Gloss Hypothesis:	HEUTE NACHT SECHS BIS ******** GRAD *** REGION     STEIGEN ZEHN GRAD ***** BIS FUENF ZWANZIG GRAD WEST
# 2026-07-13 16:55:51,263 	Gloss Alignment :	                      D             D   S                            D
# 2026-07-13 16:55:51,263 ========================================================================================================================
# 2026-07-13 16:55:51,264 Logging Sequence: 13May_2010_Thursday_tagesschau-7926
# 2026-07-13 16:55:51,264 	Gloss Reference :	REGION MEHR SONNE
# 2026-07-13 16:55:51,265 	Gloss Hypothesis:	****** MAL  SONNE
# 2026-07-13 16:55:51,265 	Gloss Alignment :	D      S
# 2026-07-13 16:55:51,265 ========================================================================================================================
# 2026-07-13 16:55:51,739 Epoch  14: Total Training Recognition Loss 232.60  Total Training Translation Loss -1.00
# 2026-07-13 16:55:51,739 Early stopping: no improvement in eval_metric for 10 epochs (best at epoch 4).
# 2026-07-13 16:55:51,740 Best validation result at step    13900:  39.81 eval_metric.
# 2026-07-13 16:56:08,949 ------------------------------------------------------------
# 2026-07-13 16:56:08,950 [DEV] partition [RECOGNITION] experiment [BW]: 1
# ================================
# COPE:  False
# ================================
# 2026-07-13 16:56:23,301 finished in 14.3514s
# 2026-07-13 16:56:23,302 ************************************************************
# 2026-07-13 16:56:23,302 [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 1
# 	WER 39.81	(DEL: 14.43,	INS: 2.77,	SUB: 22.60)
# 2026-07-13 16:56:23,302 ************************************************************
# 2026-07-13 16:56:23,303 ------------------------------------------------------------
# 2026-07-13 16:56:23,303 [DEV] partition [RECOGNITION] experiment [BW]: 2
# 2026-07-13 16:56:47,605 finished in 24.3018s
# 2026-07-13 16:56:47,606 ------------------------------------------------------------
# 2026-07-13 16:56:47,606 [DEV] partition [RECOGNITION] experiment [BW]: 3
# 2026-07-13 16:57:22,760 finished in 35.1537s
# 2026-07-13 16:57:22,760 ************************************************************
# 2026-07-13 16:57:22,761 [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 3
# 	WER 39.70	(DEL: 14.30,	INS: 2.80,	SUB: 22.60)
# 2026-07-13 16:57:22,761 ************************************************************
# 2026-07-13 16:57:22,761 ------------------------------------------------------------
# 2026-07-13 16:57:22,762 [DEV] partition [RECOGNITION] experiment [BW]: 4
# 2026-07-13 16:58:08,611 finished in 45.8493s
# 2026-07-13 16:58:08,612 ------------------------------------------------------------
# 2026-07-13 16:58:08,612 [DEV] partition [RECOGNITION] experiment [BW]: 5
# 2026-07-13 16:59:04,861 finished in 56.2491s
# 2026-07-13 16:59:04,862 ------------------------------------------------------------
# 2026-07-13 16:59:04,862 [DEV] partition [RECOGNITION] experiment [BW]: 6
# 2026-07-13 17:00:11,836 finished in 66.9743s
# 2026-07-13 17:00:11,837 ------------------------------------------------------------
# 2026-07-13 17:00:11,837 [DEV] partition [RECOGNITION] experiment [BW]: 7
# 2026-07-13 17:01:29,276 finished in 77.4389s
# 2026-07-13 17:01:29,277 ------------------------------------------------------------
# 2026-07-13 17:01:29,277 [DEV] partition [RECOGNITION] experiment [BW]: 8
# 2026-07-13 17:02:57,219 finished in 87.9419s
# 2026-07-13 17:02:57,219 ------------------------------------------------------------
# 2026-07-13 17:02:57,220 [DEV] partition [RECOGNITION] experiment [BW]: 9
# 2026-07-13 17:04:34,906 finished in 97.6861s
# 2026-07-13 17:04:34,907 ------------------------------------------------------------
# 2026-07-13 17:04:34,907 [DEV] partition [RECOGNITION] experiment [BW]: 10
# 2026-07-13 17:06:23,634 finished in 108.7273s
# 2026-07-13 17:06:23,635 ************************************************************
# 2026-07-13 17:06:23,636 [DEV] partition [Recognition & Translation] results:
# 	Best CTC Decode Beam Size: 3
# 	Best Translation Beam Size: -1 and Alpha: -1
# 	WER 39.70	(DEL: 14.30,	INS: 2.80,	SUB: 22.60)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 17:06:23,636 ************************************************************
# 2026-07-13 17:07:02,789 [TEST] partition [Recognition & Translation] results:
# 	Best CTC Decode Beam Size: 3
# 	Best Translation Beam Size: -1 and Alpha: -1
# 	WER 40.45	(DEL: 14.07,	INS: 3.78,	SUB: 22.61)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 17:07:02,790 ************************************************************

# %%
# Curves: train loss and validation loss (left), dev WER (right).
import re
import matplotlib.pyplot as plt
from main.helpers import parse_validations

MDIR = os.path.join(RUN_DIR, 'final')
val = parse_validations(MDIR)   # steps, recognition_loss (dev), wer, lr

# Train loss is logged per step in train.log, not in validations.txt.
tr_steps, tr_loss = [], []
logp = os.path.join(MDIR, 'train.log')
if os.path.exists(logp):
    for line in open(logp, encoding='utf-8', errors='ignore'):
        ms = re.search(r'Step:\s*(\d+)', line)
        ml = re.search(r'Batch Recognition Loss:\s*([\d.]+)', line)
        if ms and ml:
            tr_steps.append(int(ms.group(1)))
            tr_loss.append(float(ml.group(1)))

if not val['steps'] and not tr_steps:
    print('no logs yet in', MDIR, '(train first, DO_TRAIN = True)')
else:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4.5))

    if tr_steps:
        ax1.plot(tr_steps, tr_loss, lw=0.8, alpha=0.5, color='tab:blue', label='train loss')
    if val['steps']:
        ax1.plot(val['steps'], val['recognition_loss'], marker='o', ms=3,
                 color='tab:red', label='val loss')
    ax1.set_xlabel('step'); ax1.set_ylabel('CTC loss'); ax1.set_title('Loss')
    ax1.legend(); ax1.grid(alpha=0.3)

    if val['steps']:
        ax2.plot(val['steps'], val['wer'], marker='o', ms=3, color='crimson', label='dev WER')
        ax2.axhline(39.54, ls='--', c='gray', label='baseline (greedy) 39.54')
        good = [(s, w) for s, w in zip(val['steps'], val['wer']) if w == w]
        if good:
            bs, bw = min(good, key=lambda t: t[1])
            ax2.scatter([bs], [bw], color='black', zorder=5, label='best %.2f' % bw)
    ax2.set_xlabel('step'); ax2.set_ylabel('dev WER (%)'); ax2.set_title('Dev WER')
    ax2.legend(); ax2.grid(alpha=0.3)

    fig.tight_layout()
    fig.savefig(os.path.join(MDIR, 'training_curves.png'), dpi=120)
    plt.show()

    if val['steps']:
        good = [(s, w) for s, w in zip(val['steps'], val['wer']) if w == w]
        if good:
            bs, bw = min(good, key=lambda t: t[1])
            print('best dev WER : %.2f at step %d' % (bw, bs))
        vl = [x for x in val['recognition_loss'] if x == x]
        if vl:
            print('last val loss: %.3f' % vl[-1])
    if tr_loss:
        print('last train loss: %.3f' % tr_loss[-1])
# Out:
# best dev WER : 39.81 at step 13900
# last val loss: 38.702
# last train loss: 0.872

# %%
# Evaluate the best-on-dev checkpoint and lay the numbers next to the baseline.
best_ckpt = os.path.join(RUN_DIR, 'final', 'best.ckpt')
if not os.path.exists(best_ckpt):
    print('no best.ckpt yet -- train first (DO_TRAIN = True).')
else:
    mt.test(ACTIVE_CFG, ckpt=best_ckpt, output_path=os.path.join(RUN_DIR, 'final', 'test_output'))
    print()
    print('Baseline, from scratch, CTC only (sign.yaml):')
    print('   dev  39.54 greedy / 39.35 beam-4      test  41.53')
    print('This run, from scratch, CTC + FD-CMKD:')
    print('   see the [DEV] and [TEST] WER printed above')
    print()
    print('Reading the result:')
    print(' - below baseline beyond the margin: warm-start was hiding a real transfer.')
    print(' - within the margin: the last alternative explanation is ruled out.')
    print(' - above baseline: a weak teacher shaping the representation transfers its confusion.')
# Out:
# 2026-07-13 17:07:20,019 - ------------------------------------------------------------
# 2026-07-13 17:07:20,019 - [DEV] partition [RECOGNITION] experiment [BW]: 1
# ================================
# COPE:  False
# ================================
# 2026-07-13 17:07:34,467 - finished in 14.4479s
# 2026-07-13 17:07:34,468 - ************************************************************
# 2026-07-13 17:07:34,468 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 1
# 	WER 39.81	(DEL: 14.43,	INS: 2.77,	SUB: 22.60)
# 2026-07-13 17:07:34,469 - ************************************************************
# 2026-07-13 17:07:34,469 - ------------------------------------------------------------
# 2026-07-13 17:07:34,469 - [DEV] partition [RECOGNITION] experiment [BW]: 2
# 2026-07-13 17:07:58,449 - finished in 23.9794s
# 2026-07-13 17:07:58,449 - ------------------------------------------------------------
# 2026-07-13 17:07:58,450 - [DEV] partition [RECOGNITION] experiment [BW]: 3
# 2026-07-13 17:08:33,490 - finished in 35.0404s
# 2026-07-13 17:08:33,491 - ************************************************************
# 2026-07-13 17:08:33,491 - [DEV] partition [RECOGNITION] results:
# 	New Best CTC Decode Beam Size: 3
# 	WER 39.70	(DEL: 14.30,	INS: 2.80,	SUB: 22.60)
# 2026-07-13 17:08:33,491 - ************************************************************
# 2026-07-13 17:08:33,492 - ------------------------------------------------------------
# 2026-07-13 17:08:33,492 - [DEV] partition [RECOGNITION] experiment [BW]: 4
# 2026-07-13 17:09:18,659 - finished in 45.1672s
# 2026-07-13 17:09:18,660 - ------------------------------------------------------------
# 2026-07-13 17:09:18,660 - [DEV] partition [RECOGNITION] experiment [BW]: 5
# 2026-07-13 17:10:15,222 - finished in 56.5621s
# 2026-07-13 17:10:15,223 - ------------------------------------------------------------
# 2026-07-13 17:10:15,223 - [DEV] partition [RECOGNITION] experiment [BW]: 6
# 2026-07-13 17:11:22,810 - finished in 67.5873s
# 2026-07-13 17:11:22,811 - ------------------------------------------------------------
# 2026-07-13 17:11:22,811 - [DEV] partition [RECOGNITION] experiment [BW]: 7
# 2026-07-13 17:12:40,641 - finished in 77.8298s
# 2026-07-13 17:12:40,641 - ------------------------------------------------------------
# 2026-07-13 17:12:40,642 - [DEV] partition [RECOGNITION] experiment [BW]: 8
# 2026-07-13 17:14:06,965 - finished in 86.3233s
# 2026-07-13 17:14:06,966 - ------------------------------------------------------------
# 2026-07-13 17:14:06,966 - [DEV] partition [RECOGNITION] experiment [BW]: 9
# 2026-07-13 17:15:43,170 - finished in 96.2045s
# 2026-07-13 17:15:43,171 - ------------------------------------------------------------
# 2026-07-13 17:15:43,171 - [DEV] partition [RECOGNITION] experiment [BW]: 10
# 2026-07-13 17:17:29,865 - finished in 106.6933s
# 2026-07-13 17:17:29,865 - ************************************************************
# 2026-07-13 17:17:29,866 - [DEV] partition [Recognition & Translation] results:
# 	Best CTC Decode Beam Size: 3
# 	Best Translation Beam Size: -1 and Alpha: -1
# 	WER 39.70	(DEL: 14.30,	INS: 2.80,	SUB: 22.60)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 17:17:29,866 - ************************************************************
# 2026-07-13 17:18:09,028 - [TEST] partition [Recognition & Translation] results:
# 	Best CTC Decode Beam Size: 3
# 	Best Translation Beam Size: -1 and Alpha: -1
# 	WER 40.45	(DEL: 14.07,	INS: 3.78,	SUB: 22.61)
# 	BLEU-4 -1.00	(BLEU-1: -1.00,	BLEU-2: -1.00,	BLEU-3: -1.00,	BLEU-4: -1.00)
# 	CHRF -1.00	ROUGE -1.00
# 2026-07-13 17:18:09,029 - ************************************************************
# Baseline, from scratch, CTC only (sign.yaml):
#    dev  39.54 greedy / 39.35 beam-4      test  41.53
# This run, from scratch, CTC + FD-CMKD:
#    see the [DEV] and [TEST] WER printed above
#
# Reading the result:
#  - below baseline beyond the margin: warm-start was hiding a real transfer.
#  - within the margin: the last alternative explanation is ruled out.
#  - above baseline: a weak teacher shaping the representation transfers its confusion.
